# %%
import os
import time
import json
from glob import glob
from dotenv import load_dotenv
from langchain_community.document_loaders import Docx2txtLoader
from langchain_core.documents import Document
from langchain_upstage import UpstageEmbeddings
from pinecone import Pinecone
from langchain_pinecone import PineconeVectorStore
import tiktoken

STATE_FILE = "upload_progress.json"

# 환경 세팅
load_dotenv()
embeddings = UpstageEmbeddings(model="solar-embedding-1-large")
pc = Pinecone()
index_name = 'insurance-index-upstage'

# tiktoken 세팅 (Upstage solar-embedding-1과 호환)
tokenizer = tiktoken.get_encoding("cl100k_base")
MAX_TOKEN = 4000
CHUNK_OVERLAP = 500   # 토큰 기준

docx_files = glob('./docxfile/*.docx')
all_docs = []

print(f"총 {len(docx_files)}개 파일에서 chunk 생성 시작...")

def split_by_token(text, max_token=4000, overlap=500):
    tokens = tokenizer.encode(text)
    total = len(tokens)
    chunks = []
    start = 0
    while start < total:
        end = min(start + max_token, total)
        chunk_tokens = tokens[start:end]
        # 만약 실제 chunk가 max_token 초과면 자름 (방어적)
        while len(chunk_tokens) > max_token:
            chunk_tokens = chunk_tokens[:max_token]
        chunk_text = tokenizer.decode(chunk_tokens)
        chunks.append(chunk_text)
        start += max_token - overlap  # overlap 만큼 겹치기
    return chunks

for file_idx, filepath in enumerate(docx_files, 1):
    filename = os.path.basename(filepath)
    company_name = os.path.splitext(filename)[0]
    print(f"[{file_idx}/{len(docx_files)}] {filename} → 회사명: {company_name}")

    loader = Docx2txtLoader(filepath)
    docs = loader.load()
    text = docs[0].page_content

    # 토큰 기준으로 안전하게 분할
    chunks = split_by_token(text)
    print(f"    - {len(chunks)}개의 chunk 생성 (토큰 기준)")

    doc_objs = [Document(page_content=chunk, metadata={"company": company_name}) for chunk in chunks]
    all_docs.extend(doc_objs)

print(f"\n총 {len(all_docs)}개의 Document 객체 생성 완료.")
for idx, doc in enumerate(all_docs):
    tokens = tokenizer.encode(doc.page_content)
    if len(tokens) > 3500:
        print(f"WARNING: {idx}번 청크가 {len(tokens)}토큰 (최대 4000 초과), 자동 잘림!")
        doc.page_content = tokenizer.decode(tokens[:4000])
print("임베딩 및 Pinecone 업로드 시작...")

batch_size = 20
total_batches = (len(all_docs) + batch_size - 1) // batch_size

# 상태 파일 로딩
if os.path.exists(STATE_FILE):
    with open(STATE_FILE, "r", encoding="utf-8") as f:
        state = json.load(f)
    uploaded_batches = set(state.get("uploaded_batches", []))
    print(f"\n이전 진행 내역 발견: {len(uploaded_batches)}개 배치 이미 업로드됨. 이어서 진행합니다.")
else:
    uploaded_batches = set()

success_count = len(uploaded_batches) * batch_size

for batch_idx, i in enumerate(range(0, len(all_docs), batch_size), 1):
    batch_num = batch_idx
    batch_docs = all_docs[i:i+batch_size]
    if batch_num in uploaded_batches:
        print(f"\n[{batch_num}/{total_batches}] 이미 업로드됨 → 건너뜀")
        continue

    print(f"\n[{batch_num}/{total_batches}] {i+1}~{i+len(batch_docs)}번째 문서 임베딩+업로드 중...")

    retry = 0
    while True:
        try:
            PineconeVectorStore.from_documents(
                documents=batch_docs,
                embedding=embeddings,
                index_name=index_name,
            )
            success_count += len(batch_docs)
            print(f"    ✔️ {len(batch_docs)}개 업로드 성공 (누적 {success_count}/{len(all_docs)})")
            uploaded_batches.add(batch_num)
            with open(STATE_FILE, "w", encoding="utf-8") as f:
                json.dump({"uploaded_batches": list(uploaded_batches)}, f)
            break
        except Exception as e:
            if '429' in str(e) or 'RateLimit' in str(e):
                retry += 1
                wait_time = 60 + retry * 30   # 반복마다 점진적 대기 증가
                print(f"    ❗ RateLimit(429) 발생! {wait_time}초 후 재시도 (시도 {retry})")
                time.sleep(wait_time)
            else:
                print(f"    ❌ 알 수 없는 에러: {str(e)}")
                raise

    # 업로드 성공 후 batch 간 추가 대기 (최소 60초)
    print("    ⏳ 다음 배치까지 20초 대기")
    time.sleep(10)

print(f"\n=== Pinecone 전체 업로드 완료! 총 업로드: {success_count}개 ===")
if os.path.exists(STATE_FILE):
    os.remove(STATE_FILE)
    print(f"진행 상태파일({STATE_FILE}) 삭제 완료")
# Out:
# 총 11개 파일에서 chunk 생성 시작...
# [1/11] AXA손해보험.docx → 회사명: AXA손해보험
#     - 293개의 chunk 생성 (토큰 기준)
# [2/11] DB손해보험.docx → 회사명: DB손해보험
#     - 478개의 chunk 생성 (토큰 기준)
# [3/11] KB자동차보험.docx → 회사명: KB자동차보험
#     - 794개의 chunk 생성 (토큰 기준)
# [4/11] MG손해보험.docx → 회사명: MG손해보험
#     - 69개의 chunk 생성 (토큰 기준)
# [5/11] 롯데손해보험.docx → 회사명: 롯데손해보험
#     - 80개의 chunk 생성 (토큰 기준)
# [6/11] 메리츠.docx → 회사명: 메리츠
#     - 69개의 chunk 생성 (토큰 기준)
# [7/11] 삼성화재.docx → 회사명: 삼성화재
#     - 92개의 chunk 생성 (토큰 기준)
# [8/11] 캐롯손해보험.docx → 회사명: 캐롯손해보험
#     - 134개의 chunk 생성 (토큰 기준)
# [9/11] 하나손해보험.docx → 회사명: 하나손해보험
#     - 256개의 chunk 생성 (토큰 기준)
# [10/11] 현대해상.docx → 회사명: 현대해상
#     - 295개의 chunk 생성 (토큰 기준)
# [11/11] 흥국화재.docx → 회사명: 흥국화재
#     - 74개의 chunk 생성 (토큰 기준)
#
# 총 2634개의 Document 객체 생성 완료.
# WARNING: 0번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 3번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 4번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 5번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 6번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 7번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 8번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 9번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 10번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 11번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 12번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 13번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 14번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 15번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 16번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 17번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 18번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 19번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 20번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 21번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 22번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 23번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 24번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 25번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 26번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 27번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 28번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 29번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 30번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 31번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 32번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 33번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 34번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 35번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 36번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 37번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 38번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 39번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 40번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 41번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 42번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 43번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 44번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 45번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 46번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 47번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 48번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 49번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 50번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 51번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 52번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 53번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 54번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 55번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 56번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 57번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 58번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 59번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 60번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 61번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 62번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 63번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 64번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 65번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 66번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 67번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 68번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 69번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 70번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 71번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 72번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 73번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 74번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 75번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 76번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 77번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 78번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 79번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 80번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 81번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 82번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 83번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 84번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 85번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 86번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 87번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 88번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 89번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 90번 청크가 3998토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 91번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 92번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 93번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 94번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 95번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 96번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 97번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 98번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 99번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 100번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 101번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 102번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 103번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 104번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 105번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 106번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 107번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 108번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 109번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 110번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 111번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 112번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 113번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 114번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 115번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 116번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 117번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 118번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 119번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 120번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 121번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 122번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 123번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 124번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 125번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 126번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 127번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 128번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 129번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 130번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 131번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 132번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 133번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 134번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 135번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 136번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 137번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 138번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 139번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 140번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 141번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 142번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 143번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 144번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 145번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 146번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 147번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 148번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 149번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 150번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 151번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 152번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 153번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 154번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 155번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 156번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 157번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 158번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 159번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 160번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 161번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 162번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 163번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 164번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 165번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 166번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 167번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 168번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 169번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 170번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 171번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 172번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 173번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 174번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 175번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 176번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 177번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 178번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 179번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 180번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 181번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 182번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 183번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 184번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 185번 청크가 4001토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 186번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 187번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 188번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 189번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 190번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 191번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 192번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 193번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 194번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 195번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 196번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 197번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 198번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 199번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 200번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 201번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 202번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 203번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 204번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 205번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 206번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 207번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 208번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 209번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 210번 청크가 3998토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 211번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 212번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 213번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 214번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 215번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 216번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 217번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 218번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 219번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 220번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 221번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 222번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 223번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 224번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 225번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 226번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 227번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 228번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 229번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 230번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 231번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 232번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 233번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 234번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 235번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 236번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 237번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 238번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 239번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 240번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 241번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 242번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 243번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 244번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 245번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 246번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 247번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 248번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 249번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 250번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 251번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 252번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 253번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 254번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 255번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 256번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 257번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 258번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 259번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 260번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 261번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 262번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 263번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 264번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 265번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 266번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 267번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 268번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 269번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 270번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 271번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 272번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 273번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 274번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 275번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 276번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 277번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 278번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 279번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 280번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 281번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 282번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 283번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 284번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 285번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 286번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 287번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 288번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 289번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 290번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 291번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 293번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 294번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 295번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 296번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 297번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 298번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 299번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 300번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 301번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 302번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 303번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 304번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 305번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 306번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 307번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 308번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 309번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 310번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 311번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 312번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 313번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 314번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 315번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 316번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 317번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 318번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 319번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 320번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 321번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 322번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 323번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 324번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 325번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 326번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 327번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 328번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 329번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 330번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 331번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 332번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 333번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 334번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 335번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 336번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 337번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 338번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 339번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 340번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 341번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 342번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 343번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 344번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 345번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 346번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 347번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 348번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 349번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 350번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 351번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 352번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 353번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 354번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 355번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 356번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 357번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 358번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 359번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 360번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 361번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 362번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 363번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 364번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 365번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 366번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 367번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 368번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 369번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 370번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 371번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 372번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 373번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 374번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 375번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 376번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 377번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 378번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 379번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 380번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 381번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 382번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 383번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 384번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 385번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 386번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 387번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 388번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 389번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 390번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 391번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 392번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 393번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 394번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 395번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 396번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 397번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 398번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 399번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 400번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 401번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 402번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 403번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 404번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 405번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 406번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 407번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 408번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 409번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 410번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 411번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 412번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 413번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 414번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 415번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 416번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 417번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 418번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 419번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 420번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 421번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 422번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 423번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 424번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 425번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 426번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 427번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 428번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 429번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 430번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 431번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 432번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 433번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 434번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 435번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 436번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 437번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 438번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 439번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 440번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 441번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 442번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 443번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 444번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 445번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 446번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 447번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 448번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 449번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 450번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 451번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 452번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 453번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 454번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 455번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 456번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 457번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 458번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 459번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 460번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 461번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 462번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 463번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 464번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 465번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 466번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 467번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 468번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 469번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 470번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 471번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 472번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 473번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 474번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 475번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 476번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 477번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 478번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 479번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 480번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 481번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 482번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 483번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 484번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 485번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 486번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 487번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 488번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 489번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 490번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 491번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 492번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 493번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 494번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 495번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 496번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 497번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 498번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 499번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 500번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 501번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 502번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 503번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 504번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 505번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 506번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 507번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 508번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 509번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 510번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 511번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 512번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 513번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 514번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 515번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 516번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 517번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 518번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 519번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 520번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 521번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 522번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 523번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 524번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 525번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 526번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 527번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 528번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 529번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 530번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 531번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 532번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 533번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 534번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 535번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 536번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 537번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 538번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 539번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 540번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 541번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 542번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 543번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 544번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 545번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 546번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 547번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 548번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 549번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 550번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 551번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 552번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 553번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 554번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 555번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 556번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 557번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 558번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 559번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 560번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 561번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 562번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 563번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 564번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 565번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 566번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 567번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 568번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 569번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 570번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 571번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 572번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 573번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 574번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 575번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 576번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 577번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 578번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 579번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 580번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 581번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 582번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 583번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 584번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 585번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 586번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 587번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 588번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 589번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 590번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 591번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 592번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 593번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 594번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 595번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 596번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 597번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 598번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 599번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 600번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 601번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 602번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 603번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 604번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 605번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 606번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 607번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 608번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 609번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 610번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 611번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 612번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 613번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 614번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 615번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 616번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 617번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 618번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 619번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 620번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 621번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 622번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 623번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 624번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 625번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 626번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 627번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 628번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 629번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 630번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 631번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 632번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 633번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 634번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 635번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 636번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 637번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 638번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 639번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 640번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 641번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 642번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 643번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 644번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 645번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 646번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 647번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 648번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 649번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 650번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 651번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 652번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 653번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 654번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 655번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 656번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 657번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 658번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 659번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 660번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 661번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 662번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 663번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 664번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 665번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 666번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 667번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 668번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 669번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 670번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 671번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 672번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 673번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 674번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 675번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 676번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 677번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 678번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 679번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 680번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 681번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 682번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 683번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 684번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 685번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 686번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 687번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 688번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 689번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 690번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 691번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 692번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 693번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 694번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 695번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 696번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 697번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 698번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 699번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 700번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 701번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 702번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 703번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 704번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 705번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 706번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 707번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 708번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 709번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 710번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 711번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 712번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 713번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 714번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 715번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 716번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 717번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 718번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 719번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 720번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 721번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 722번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 723번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 724번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 725번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 726번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 727번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 728번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 729번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 730번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 731번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 732번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 733번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 734번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 735번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 736번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 737번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 738번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 739번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 740번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 741번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 742번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 743번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 744번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 745번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 746번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 747번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 748번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 749번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 750번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 751번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 752번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 753번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 754번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 755번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 756번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 757번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 758번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 759번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 760번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 761번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 762번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 763번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 764번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 765번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 766번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 767번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 768번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 769번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 771번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 772번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 773번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 774번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 775번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 776번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 777번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 778번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 779번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 780번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 781번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 782번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 783번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 784번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 785번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 786번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 787번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 788번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 789번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 790번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 791번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 792번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 793번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 794번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 795번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 796번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 797번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 798번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 799번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 800번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 801번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 802번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 803번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 804번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 805번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 806번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 807번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 808번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 809번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 810번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 811번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 812번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 813번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 814번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 815번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 816번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 817번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 818번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 819번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 820번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 821번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 822번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 823번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 824번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 825번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 826번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 827번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 828번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 829번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 830번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 831번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 832번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 833번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 834번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 835번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 836번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 837번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 838번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 839번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 840번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 841번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 842번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 843번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 844번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 845번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 846번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 847번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 848번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 849번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 850번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 851번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 852번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 853번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 854번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 855번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 856번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 857번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 858번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 859번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 860번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 861번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 862번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 863번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 864번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 865번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 866번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 867번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 868번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 869번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 870번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 871번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 872번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 873번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 874번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 875번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 876번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 877번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 878번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 879번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 880번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 881번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 882번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 883번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 884번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 885번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 886번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 887번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 888번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 889번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 890번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 891번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 892번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 893번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 894번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 895번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 896번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 897번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 898번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 899번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 900번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 901번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 902번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 903번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 904번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 905번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 906번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 907번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 908번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 909번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 910번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 911번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 912번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 913번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 914번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 915번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 916번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 917번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 918번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 919번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 920번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 921번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 922번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 923번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 924번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 925번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 926번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 927번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 928번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 929번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 930번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 931번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 932번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 933번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 934번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 935번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 936번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 937번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 938번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 939번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 940번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 941번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 942번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 943번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 944번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 945번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 946번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 947번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 948번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 949번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 950번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 951번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 952번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 953번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 954번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 955번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 956번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 957번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 958번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 959번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 960번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 961번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 962번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 963번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 964번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 965번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 966번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 967번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 968번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 969번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 970번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 971번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 972번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 973번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 974번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 975번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 976번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 977번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 978번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 979번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 980번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 981번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 982번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 983번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 984번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 985번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 986번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 987번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 988번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 989번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 990번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 991번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 992번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 993번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 994번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 995번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 996번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 997번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 998번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 999번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1000번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1001번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1002번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1003번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1004번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1005번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1006번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1007번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1008번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1009번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1010번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1011번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1012번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1013번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1014번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1015번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1016번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1017번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1018번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1019번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1020번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1021번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1022번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1023번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1024번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1025번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1026번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1027번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1028번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1029번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 1030번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# ...
# WARNING: 2427번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2428번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2429번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2430번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2431번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2432번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2433번 청크가 3998토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2434번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2435번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2436번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2437번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2438번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2439번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2440번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2441번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2442번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2443번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2444번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2445번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2446번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2447번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2448번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2449번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2450번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2451번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2452번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2453번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2454번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2455번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2456번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2457번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2458번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2459번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2460번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2461번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2462번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2463번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2464번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2465번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2466번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2467번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2468번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2469번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2470번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2471번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2472번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2473번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2474번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2475번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2476번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2477번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2478번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2479번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2480번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2481번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2482번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2483번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2484번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2485번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2486번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2487번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2488번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2489번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2490번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2491번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2492번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2493번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2494번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2495번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2496번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2497번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2498번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2499번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2500번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2501번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2502번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2503번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2504번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2505번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2506번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2507번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2508번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2509번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2510번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2511번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2512번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2513번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2514번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2515번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2516번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2517번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2518번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2519번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2520번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2521번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2522번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2523번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2524번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2525번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2526번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2527번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2528번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2529번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2530번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2531번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2532번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2533번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2534번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2535번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2536번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2537번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2538번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2539번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2540번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2541번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2542번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2543번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2544번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2545번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2546번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2547번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2548번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2549번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2550번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2551번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2552번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2553번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2554번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2555번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2556번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2557번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2558번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2560번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2561번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2562번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2563번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2564번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2565번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2566번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2567번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2568번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2569번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2570번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2571번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2572번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2573번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2574번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2575번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2576번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2577번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2578번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2579번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2580번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2581번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2582번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2583번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2584번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2585번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2586번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2587번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2588번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2589번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2590번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2591번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2592번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2593번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2594번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2595번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2596번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2597번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2598번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2599번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2600번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2601번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2602번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2603번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2604번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2605번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2606번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2607번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2608번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2609번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2610번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2611번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2612번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2613번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2614번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2615번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2616번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2617번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2618번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2619번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2620번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2621번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2622번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2623번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2624번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2625번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2626번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2627번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2628번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2629번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2630번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2631번 청크가 4000토큰 (최대 4000 초과), 자동 잘림!
# WARNING: 2632번 청크가 3999토큰 (최대 4000 초과), 자동 잘림!
# 임베딩 및 Pinecone 업로드 시작...
#
# 이전 진행 내역 발견: 29개 배치 이미 업로드됨. 이어서 진행합니다.
#
# [1/132] 이미 업로드됨 → 건너뜀
#
# [2/132] 이미 업로드됨 → 건너뜀
#
# [3/132] 이미 업로드됨 → 건너뜀
#
# [4/132] 이미 업로드됨 → 건너뜀
#
# [5/132] 이미 업로드됨 → 건너뜀
#
# [6/132] 이미 업로드됨 → 건너뜀
#
# [7/132] 이미 업로드됨 → 건너뜀
#
# [8/132] 이미 업로드됨 → 건너뜀
#
# [9/132] 이미 업로드됨 → 건너뜀
#
# [10/132] 이미 업로드됨 → 건너뜀
#
# [11/132] 이미 업로드됨 → 건너뜀
#
# [12/132] 이미 업로드됨 → 건너뜀
#
# [13/132] 이미 업로드됨 → 건너뜀
#
# [14/132] 이미 업로드됨 → 건너뜀
#
# [15/132] 이미 업로드됨 → 건너뜀
#
# [16/132] 이미 업로드됨 → 건너뜀
#
# [17/132] 이미 업로드됨 → 건너뜀
#
# [18/132] 이미 업로드됨 → 건너뜀
#
# [19/132] 이미 업로드됨 → 건너뜀
#
# [20/132] 이미 업로드됨 → 건너뜀
#
# [21/132] 이미 업로드됨 → 건너뜀
#
# [22/132] 이미 업로드됨 → 건너뜀
#
# [23/132] 이미 업로드됨 → 건너뜀
#
# [24/132] 이미 업로드됨 → 건너뜀
#
# [25/132] 이미 업로드됨 → 건너뜀
#
# [26/132] 이미 업로드됨 → 건너뜀
#
# [27/132] 이미 업로드됨 → 건너뜀
#
# [28/132] 이미 업로드됨 → 건너뜀
#
# [29/132] 이미 업로드됨 → 건너뜀
#
# [30/132] 581~600번째 문서 임베딩+업로드 중...
#     ❌ 알 수 없는 에러: Error code: 400 - {'error': {'message': "This model's maximum context length is 4000 tokens, but your request contains 5165 tokens. Please reduce the length of your input text or select only the most relevant portions to include in your request. For information on token counting methods and model-specific limits, please refer to our API reference documentation (https://console.upstage.ai/api/embeddings)", 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_body'}}
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[5], line 97
#      95 while True:
#      96     try:
# ---> 97         PineconeVectorStore.from_documents(
#      98             documents=batch_docs,
#      99             embedding=embeddings,
#     100             index_name=index_name,
#     101         )
#     102         success_count += len(batch_docs)
#     103         print(f"    ✔️ {len(batch_docs)}개 업로드 성공 (누적 {success_count}/{len(all_docs)})")
#
# File c:\Users\Admin\anaconda3\envs\hee\lib\site-packages\langchain_core\vectorstores\base.py:848, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     845     if any(ids):
#     846         kwargs["ids"] = ids
# --> 848 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File c:\Users\Admin\anaconda3\envs\hee\lib\site-packages\langchain_pinecone\vectorstores.py:911, in PineconeVectorStore.from_texts(cls, texts, embedding, metadatas, ids, batch_size, text_key, namespace, index_name, upsert_kwargs, pool_threads, embeddings_chunk_size, async_req, id_prefix, **kwargs)
#     908 pinecone_index = cls.get_pinecone_index(index_name, pool_threads)
#     909 pinecone = cls(pinecone_index, embedding, text_key, namespace, **kwargs)
# --> 911 pinecone.add_texts(
#     912     texts,
#     913     metadatas=metadatas,
#     914     ids=ids,
#     915     namespace=namespace,
#     916     batch_size=batch_size,
#     917     embedding_chunk_size=embeddings_chunk_size,
#     918     async_req=async_req,
#     919     id_prefix=id_prefix,
#     920     **(upsert_kwargs or {}),
#     921 )
#     922 return pinecone
#
# File c:\Users\Admin\anaconda3\envs\hee\lib\site-packages\langchain_pinecone\vectorstores.py:343, in PineconeVectorStore.add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, async_req, id_prefix, **kwargs)
#     341 chunk_ids = ids[i : i + embedding_chunk_size]
#     342 chunk_metadatas = metadatas[i : i + embedding_chunk_size]
# --> 343 embeddings = self._embedding.embed_documents(chunk_texts)
#     344 vector_tuples = list(zip(chunk_ids, embeddings, chunk_metadatas))
#     345 if async_req:
#     346     # Runs the pinecone upsert asynchronously.
#
# File c:\Users\Admin\anaconda3\envs\hee\lib\site-packages\langchain_upstage\embeddings.py:216, in UpstageEmbeddings.embed_documents(self, texts)
#     214 for i in range(0, len(texts), batch_size):
#     215     batch = texts[i : i + batch_size]
# --> 216     data = self.client.create(input=batch, **params).data
#     217     embeddings.extend([r.embedding for r in data])
#     219 return embeddings
#
# File c:\Users\Admin\anaconda3\envs\hee\lib\site-packages\openai\resources\embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File c:\Users\Admin\anaconda3\envs\hee\lib\site-packages\openai\_base_client.py:1256, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1242 def post(
#    1243     self,
#    1244     path: str,
#    (...)
#    1251     stream_cls: type[_StreamT] | None = None,
#    1252 ) -> ResponseT | _StreamT:
#    1253     opts = FinalRequestOptions.construct(
#    1254         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1255     )
# -> 1256     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Admin\anaconda3\envs\hee\lib\site-packages\openai\_base_client.py:1044, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1041             err.response.read()
#    1043         log.debug("Re-raising status error")
# -> 1044         raise self._make_status_error_from_response(err.response) from None
#    1046     break
#    1048 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': "This model's maximum context length is 4000 tokens, but your request contains 5165 tokens. Please reduce the length of your input text or select only the most relevant portions to include in your request. For information on token counting methods and model-specific limits, please refer to our API reference documentation (https://console.upstage.ai/api/embeddings)", 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_body'}}

# %%
import os
import time
import json
from glob import glob
from dotenv import load_dotenv
from langchain_community.document_loaders import Docx2txtLoader
from langchain_core.documents import Document
from langchain_upstage import UpstageEmbeddings
from pinecone import Pinecone
from langchain_pinecone import PineconeVectorStore
import tiktoken

STATE_FILE = "upload_progress.json"

# 환경 세팅
load_dotenv()
embeddings = UpstageEmbeddings(model="solar-embedding-1-large")
pc = Pinecone()
index_name = 'insurance-index-upstage'

tokenizer = tiktoken.get_encoding("cl100k_base")
MAX_TOKEN = 4000
CHUNK_OVERLAP = 500

docx_files = glob('./docxfile/*.docx')
all_docs = []

print(f"총 {len(docx_files)}개 파일에서 chunk 생성 시작...")

def split_by_token(text, max_token=MAX_TOKEN, overlap=CHUNK_OVERLAP):
    tokens = tokenizer.encode(text)
    total = len(tokens)
    chunks = []
    start = 0
    while start < total:
        end = min(start + max_token, total)
        chunk_tokens = tokens[start:end]
        chunk_text = tokenizer.decode(chunk_tokens)
        # decode 결과가 max_token을 넘을 수도 있으니 다시 체크
        chunk_tokens = tokenizer.encode(chunk_text)
        if len(chunk_tokens) > max_token:
            chunk_text = tokenizer.decode(chunk_tokens[:max_token])
        chunks.append(chunk_text)
        start += max_token - overlap
    return chunks

# 1. 문서별 청크 생성
for file_idx, filepath in enumerate(docx_files, 1):
    filename = os.path.basename(filepath)
    company_name = os.path.splitext(filename)[0]
    print(f"[{file_idx}/{len(docx_files)}] {filename} → 회사명: {company_name}")

    loader = Docx2txtLoader(filepath)
    docs = loader.load()
    text = docs[0].page_content

    # 토큰 기준으로 청크 생성
    chunks = split_by_token(text)
    print(f"    - {len(chunks)}개의 chunk 생성 (토큰 기준)")

    doc_objs = [Document(page_content=chunk, metadata={"company": company_name}) for chunk in chunks]
    all_docs.extend(doc_objs)

print(f"\n총 {len(all_docs)}개의 Document 객체 생성 완료.")

# 2. 업로드 전 2중 방어: 모든 청크 토큰 길이 체크 및 자르기
for idx, doc in enumerate(all_docs):
    tokens = tokenizer.encode(doc.page_content)
    if len(tokens) > MAX_TOKEN:
        print(f"WARNING: {idx}번 청크가 {len(tokens)}토큰 (최대 {MAX_TOKEN} 초과), 자동 잘림!")
        doc.page_content = tokenizer.decode(tokens[:MAX_TOKEN])

print("임베딩 및 Pinecone 업로드 시작...")

batch_size = 20
total_batches = (len(all_docs) + batch_size - 1) // batch_size

# 상태 파일 로딩
if os.path.exists(STATE_FILE):
    with open(STATE_FILE, "r", encoding="utf-8") as f:
        state = json.load(f)
    uploaded_batches = set(state.get("uploaded_batches", []))
    print(f"\n이전 진행 내역 발견: {len(uploaded_batches)}개 배치 이미 업로드됨. 이어서 진행합니다.")
else:
    uploaded_batches = set()

success_count = len(uploaded_batches) * batch_size

for batch_idx, i in enumerate(range(0, len(all_docs), batch_size), 1):
    batch_num = batch_idx
    batch_docs = all_docs[i:i+batch_size]
    if batch_num in uploaded_batches:
        print(f"\n[{batch_num}/{total_batches}] 이미 업로드됨 → 건너뜀")
        continue

    print(f"\n[{batch_num}/{total_batches}] {i+1}~{i+len(batch_docs)}번째 문서 임베딩+업로드 중...")

    retry = 0
    while True:
        try:
            PineconeVectorStore.from_documents(
                documents=batch_docs,
                embedding=embeddings,
                index_name=index_name,
            )
            success_count += len(batch_docs)
            print(f"    ✔️ {len(batch_docs)}개 업로드 성공 (누적 {success_count}/{len(all_docs)})")
            uploaded_batches.add(batch_num)
            with open(STATE_FILE, "w", encoding="utf-8") as f:
                json.dump({"uploaded_batches": list(uploaded_batches)}, f)
            break
        except Exception as e:
            if '429' in str(e) or 'RateLimit' in str(e):
                retry += 1
                wait_time = 20  # 항상 20초 대기 (고정)
                print(f"    ❗ RateLimit(429) 발생! {wait_time}초 후 재시도 (시도 {retry})")
                time.sleep(wait_time)
            else:
                print(f"    ❌ 알 수 없는 에러: {str(e)}")
                raise

    # 업로드 성공 후 batch 간 20초 대기
    print("    ⏳ 다음 배치까지 20초 대기")
    time.sleep(20)

print(f"\n=== Pinecone 전체 업로드 완료! 총 업로드: {success_count}개 ===")
if os.path.exists(STATE_FILE):
    os.remove(STATE_FILE)
    print(f"진행 상태파일({STATE_FILE}) 삭제 완료")
# Out:
# 총 11개 파일에서 chunk 생성 시작...
# [1/11] AXA손해보험.docx → 회사명: AXA손해보험
#     - 293개의 chunk 생성 (토큰 기준)
# [2/11] DB손해보험.docx → 회사명: DB손해보험
#     - 478개의 chunk 생성 (토큰 기준)
# [3/11] KB자동차보험.docx → 회사명: KB자동차보험
#     - 794개의 chunk 생성 (토큰 기준)
# [4/11] MG손해보험.docx → 회사명: MG손해보험
#     - 69개의 chunk 생성 (토큰 기준)
# [5/11] 롯데손해보험.docx → 회사명: 롯데손해보험
#     - 80개의 chunk 생성 (토큰 기준)
# [6/11] 메리츠.docx → 회사명: 메리츠
#     - 69개의 chunk 생성 (토큰 기준)
# [7/11] 삼성화재.docx → 회사명: 삼성화재
#     - 92개의 chunk 생성 (토큰 기준)
# [8/11] 캐롯손해보험.docx → 회사명: 캐롯손해보험
#     - 134개의 chunk 생성 (토큰 기준)
# [9/11] 하나손해보험.docx → 회사명: 하나손해보험
#     - 256개의 chunk 생성 (토큰 기준)
# [10/11] 현대해상.docx → 회사명: 현대해상
#     - 295개의 chunk 생성 (토큰 기준)
# [11/11] 흥국화재.docx → 회사명: 흥국화재
#     - 74개의 chunk 생성 (토큰 기준)
#
# 총 2634개의 Document 객체 생성 완료.
# 임베딩 및 Pinecone 업로드 시작...
#
# 이전 진행 내역 발견: 29개 배치 이미 업로드됨. 이어서 진행합니다.
#
# [1/132] 이미 업로드됨 → 건너뜀
#
# [2/132] 이미 업로드됨 → 건너뜀
#
# [3/132] 이미 업로드됨 → 건너뜀
#
# [4/132] 이미 업로드됨 → 건너뜀
#
# [5/132] 이미 업로드됨 → 건너뜀
#
# [6/132] 이미 업로드됨 → 건너뜀
#
# [7/132] 이미 업로드됨 → 건너뜀
#
# [8/132] 이미 업로드됨 → 건너뜀
#
# [9/132] 이미 업로드됨 → 건너뜀
#
# [10/132] 이미 업로드됨 → 건너뜀
#
# [11/132] 이미 업로드됨 → 건너뜀
#
# [12/132] 이미 업로드됨 → 건너뜀
#
# [13/132] 이미 업로드됨 → 건너뜀
#
# [14/132] 이미 업로드됨 → 건너뜀
#
# [15/132] 이미 업로드됨 → 건너뜀
#
# [16/132] 이미 업로드됨 → 건너뜀
#
# [17/132] 이미 업로드됨 → 건너뜀
#
# [18/132] 이미 업로드됨 → 건너뜀
#
# [19/132] 이미 업로드됨 → 건너뜀
#
# [20/132] 이미 업로드됨 → 건너뜀
#
# [21/132] 이미 업로드됨 → 건너뜀
#
# [22/132] 이미 업로드됨 → 건너뜀
#
# [23/132] 이미 업로드됨 → 건너뜀
#
# [24/132] 이미 업로드됨 → 건너뜀
#
# [25/132] 이미 업로드됨 → 건너뜀
#
# [26/132] 이미 업로드됨 → 건너뜀
#
# [27/132] 이미 업로드됨 → 건너뜀
#
# [28/132] 이미 업로드됨 → 건너뜀
#
# [29/132] 이미 업로드됨 → 건너뜀
#
# [30/132] 581~600번째 문서 임베딩+업로드 중...
#     ❌ 알 수 없는 에러: Error code: 400 - {'error': {'message': "This model's maximum context length is 4000 tokens, but your request contains 5165 tokens. Please reduce the length of your input text or select only the most relevant portions to include in your request. For information on token counting methods and model-specific limits, please refer to our API reference documentation (https://console.upstage.ai/api/embeddings)", 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_body'}}
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[6], line 101
#      99 while True:
#     100     try:
# --> 101         PineconeVectorStore.from_documents(
#     102             documents=batch_docs,
#     103             embedding=embeddings,
#     104             index_name=index_name,
#     105         )
#     106         success_count += len(batch_docs)
#     107         print(f"    ✔️ {len(batch_docs)}개 업로드 성공 (누적 {success_count}/{len(all_docs)})")
#
# File c:\Users\Admin\anaconda3\envs\hee\lib\site-packages\langchain_core\vectorstores\base.py:848, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     845     if any(ids):
#     846         kwargs["ids"] = ids
# --> 848 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File c:\Users\Admin\anaconda3\envs\hee\lib\site-packages\langchain_pinecone\vectorstores.py:911, in PineconeVectorStore.from_texts(cls, texts, embedding, metadatas, ids, batch_size, text_key, namespace, index_name, upsert_kwargs, pool_threads, embeddings_chunk_size, async_req, id_prefix, **kwargs)
#     908 pinecone_index = cls.get_pinecone_index(index_name, pool_threads)
#     909 pinecone = cls(pinecone_index, embedding, text_key, namespace, **kwargs)
# --> 911 pinecone.add_texts(
#     912     texts,
#     913     metadatas=metadatas,
#     914     ids=ids,
#     915     namespace=namespace,
#     916     batch_size=batch_size,
#     917     embedding_chunk_size=embeddings_chunk_size,
#     918     async_req=async_req,
#     919     id_prefix=id_prefix,
#     920     **(upsert_kwargs or {}),
#     921 )
#     922 return pinecone
#
# File c:\Users\Admin\anaconda3\envs\hee\lib\site-packages\langchain_pinecone\vectorstores.py:343, in PineconeVectorStore.add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, async_req, id_prefix, **kwargs)
#     341 chunk_ids = ids[i : i + embedding_chunk_size]
#     342 chunk_metadatas = metadatas[i : i + embedding_chunk_size]
# --> 343 embeddings = self._embedding.embed_documents(chunk_texts)
#     344 vector_tuples = list(zip(chunk_ids, embeddings, chunk_metadatas))
#     345 if async_req:
#     346     # Runs the pinecone upsert asynchronously.
#
# File c:\Users\Admin\anaconda3\envs\hee\lib\site-packages\langchain_upstage\embeddings.py:216, in UpstageEmbeddings.embed_documents(self, texts)
#     214 for i in range(0, len(texts), batch_size):
#     215     batch = texts[i : i + batch_size]
# --> 216     data = self.client.create(input=batch, **params).data
#     217     embeddings.extend([r.embedding for r in data])
#     219 return embeddings
#
# File c:\Users\Admin\anaconda3\envs\hee\lib\site-packages\openai\resources\embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File c:\Users\Admin\anaconda3\envs\hee\lib\site-packages\openai\_base_client.py:1256, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1242 def post(
#    1243     self,
#    1244     path: str,
#    (...)
#    1251     stream_cls: type[_StreamT] | None = None,
#    1252 ) -> ResponseT | _StreamT:
#    1253     opts = FinalRequestOptions.construct(
#    1254         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1255     )
# -> 1256     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Admin\anaconda3\envs\hee\lib\site-packages\openai\_base_client.py:1044, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1041             err.response.read()
#    1043         log.debug("Re-raising status error")
# -> 1044         raise self._make_status_error_from_response(err.response) from None
#    1046     break
#    1048 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': "This model's maximum context length is 4000 tokens, but your request contains 5165 tokens. Please reduce the length of your input text or select only the most relevant portions to include in your request. For information on token counting methods and model-specific limits, please refer to our API reference documentation (https://console.upstage.ai/api/embeddings)", 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_body'}}

# %%
query = "피의자가 음주운전을 해서 피해를 받으면 보상이 있나요?"
retrieved_docs = database.similarity_search(query,
                                            k=3, # 기본 k는 4이며, 최대 k는 100이다.
                                            )
# ai_message = qa_chain.invoke({'query':query})
# ai_message

# %%
prompt = f'''[identity]
- 당신은 최고의 한국 보험 전문가입니다
- [context]를 참고해서 사용자의 질문에 답변해 주세요
[context]는 다음과 같습니다
{retrieved_docs}
Question: {query}'''

# %%
ai_message = llm.invoke(prompt)

# %%
print(ai_message.content)
# Out:
# 네, 음주운전으로 인한 피해의 경우 보험에서 보상이 가능합니다. 특히, 형사합의 지원금 특별약관과 변호사선임비용 지원 특별약관에 따라, 음주운전으로 인한 사고로 피보험자가 법률상 손해배상책임을 지게 되거나 법적 절차가 진행되는 경우, 보험금이 지급될 수 있습니다.
#
# 구체적으로는, 보험약관에서는 피보험자가 무면허운전 또는 음주운전으로 사고를 낸 경우 보험금이 지급되지 않는 경우가 명시되어 있지만, 만약 사고가 발생하고 법률상 손해배상책임이 발생했으며, 관련 서류(예를 들어, 경찰서 교통사고사실확인원, 형사합의서 등)를 제출할 경우 보험금 지급 대상이 될 수 있습니다.
#
# 또한, 만약 사고로 인해 형사합의금 또는 변호사 선임 비용이 발생했다면, 해당 내용으로 보험금을 청구할 수 있으며, 실손으로 보상받거나 지원하는 방식으로 처리됩니다.
#
# 요약하자면, 음주운전 사고로 피해를 입은 경우, 사고 사실에 대한 적절한 증빙 서류와 함께 보험사에 청구하면 일정 부분 보험혜택을 받을 수 있습니다.
