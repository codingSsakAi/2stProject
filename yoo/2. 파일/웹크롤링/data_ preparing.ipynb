# %%
import pandas as pd

# %%
# csv 파일 불러오기 
data = pd.read_csv(r'C:\Users\Admin\Desktop\2차 프로젝트\2.코드\웹크롤링\데이터\1.보험용어\2.변환본(가공,최종)\보험용어 취합본(정리중).csv', encoding="utf-8")
data.head(5)
# Out:
#     id                    term  \
# 0  519              (영업용) 집기비품
# 1  519              (영업용) 집기비품
# 2  534  (자동)갱신계약 → (자동)재계약 / /
# 3  534  (자동)갱신계약 → (자동)재계약 / /
# 4  113               12대 중과실사고
#
#                                          description source  \
# 0  일반적으로 직업상의 필요에서 사용 도는 소지되는 것으로 점포나 사무실, 작업장에 소...   KNIA
# 1  일반적으로 직업상의 필요에서 사용 도는 소지되는 것으로 점포나 사무실, 작업장에 소...   KNIA
# 2                                  근거법령(보험업감독업무시행세칙)   DB생명
# 3                                  근거법령(보험업감독업무시행세칙)   DB생명
# 4  교통사고처리특례법' 제3조(처벌의 특례)에 규정돼 있는 것으로, 이는 보험 가입 여...   KNIA
#
#         collected_date
# 0  2025-08-14 12:21:26
# 1  2025-08-14 12:21:26
# 2  2025-08-14 13:18:54
# 3  2025-08-14 13:18:54
# 4  2025-08-14 12:21:26

# %%
# term과 description 둘 다 같은 행을 찾기 
dup_mask = data.duplicated(subset=["term","description"], keep=False)
data[dup_mask]
# Out:
#        id                    term  \
# 0     519              (영업용) 집기비품
# 1     519              (영업용) 집기비품
# 2     534  (자동)갱신계약 → (자동)재계약 / /
# 3     534  (자동)갱신계약 → (자동)재계약 / /
# 4     113               12대 중과실사고
# ...   ...                     ...
# 5035  117                    휴항환급
# 5036  118                    희망이익
# 5037  787                    희망이익
# 5038  118                    희망이익
# 5039  787                    희망이익
#
#                                             description      source  \
# 0     일반적으로 직업상의 필요에서 사용 도는 소지되는 것으로 점포나 사무실, 작업장에 소...        KNIA
# 1     일반적으로 직업상의 필요에서 사용 도는 소지되는 것으로 점포나 사무실, 작업장에 소...        KNIA
# 2                                     근거법령(보험업감독업무시행세칙)        DB생명
# 3                                     근거법령(보험업감독업무시행세칙)        DB생명
# 4     교통사고처리특례법' 제3조(처벌의 특례)에 규정돼 있는 것으로, 이는 보험 가입 여...        KNIA
# ...                                                 ...         ...
# 5035  피보험선박이 입거수선 기타의 이유로 항해를 휴지한 경우에는 위험은 어느 정도 감소하...  KIDI_BIGIN
# ...
