# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# # <span style="color:red"> Step.3_추출 데이터 기본정제 </span>

# %%
import os
import re

def basic_text_cleaning(text):
    """기본적인 텍스트 정제"""
    
    print("기본 정제 시작...")
    
    # 1. 과도한 줄바꿈 정리 (3개 이상 → 2개)
    text = re.sub(r'\n\s*\n\s*\n+', '\n\n', text)
    print("✓ 과도한 줄바꿈 정리 완료")
    
    # 2. 각 줄의 앞뒤 공백 제거 및 중간 공백 정리
    lines = text.split('\n')
    cleaned_lines = []
    
    for line in lines:
        # 앞뒤 공백 제거
        line = line.strip()
        
        # 과도한 중간 공백 정리 (2개 이상 공백을 1개로)
        line = re.sub(r'\s{2,}', ' ', line)
        
        # 탭 문자를 공백으로 변환
        line = line.replace('\t', ' ')
        
        cleaned_lines.append(line)
    
    print("✓ 공백 정리 완료")
    
    # 3. 연속된 빈 줄 정리
    final_lines = []
    prev_empty = False
    
    for line in cleaned_lines:
        if line == "":
            if not prev_empty:
                final_lines.append(line)
            prev_empty = True
        else:
            final_lines.append(line)
            prev_empty = False
    
    print("✓ 빈 줄 정리 완료")
    
    return '\n'.join(final_lines)

def remove_repetitive_headers(text):
    """반복되는 헤더/푸터/제목 제거"""
    
    print("중복 콘텐츠 제거 시작...")
    
    lines = text.split('\n')
    
    # 페이지 번호만 있는 줄 제거
    lines = [line for line in lines if not re.match(r'^\s*\d+\s*$', line)]
    print("✓ 페이지 번호 제거 완료")
    
    # 자주 반복되는 줄 찾기 (5자 이상의 의미있는 줄만)
    line_counts = {}
    for line in lines:
        if line.strip() and len(line.strip()) > 5:
            clean_line = line.strip()
            line_counts[clean_line] = line_counts.get(clean_line, 0) + 1
    
    # 3번 이상 반복되는 줄들을 헤더/푸터로 간주
    repetitive_lines = set()
    for line, count in line_counts.items():
        if count >= 3:
            # 단, 중요한 법령이나 조문은 제외
            if not any(keyword in line for keyword in ['조', '항', '과실비율', '도로교통법']):
                repetitive_lines.add(line)
    
    print(f"✓ {len(repetitive_lines)}개의 반복 줄 발견")
    
    # 반복 줄 제거
    cleaned_lines = []
    for line in lines:
        if line.strip() not in repetitive_lines:
            cleaned_lines.append(line)
    
    print("✓ 중복 콘텐츠 제거 완료")
    
    return '\n'.join(cleaned_lines)

def normalize_headers(text):
    """제목 구조 정규화"""
    
    print("제목 구조 정규화 시작...")
    
    lines = text.split('\n')
    normalized_lines = []
    
    for line in lines:
        original_line = line
        line = line.strip()
        
        if not line:
            normalized_lines.append('')
            continue
        
        # 이미 마크다운 헤더인 경우 패스
        if line.startswith('#'):
            normalized_lines.append(original_line)
            continue
        
        # 1. 페이지 제목 (# 페이지 X)
        if line.startswith('페이지 ') and re.match(r'^페이지\s+\d+', line):
            normalized_lines.append(f"# {line}")
            continue
        
        # 2. 숫자로 시작하는 대제목 (1., 2., 1), 2) 등)
        if re.match(r'^[\d]+[\.\)]\s+[가-힣]', line):
            normalized_lines.append(f"## {line}")
            continue
        
        # 3. 조문 제목 (제1조, 제2조 등)
        if re.match(r'^제\s*\d+\s*조', line):
            normalized_lines.append(f"### {line}")
            continue
        
        # 4. 항목 제목 (가., 나., 다. 등)
        if re.match(r'^[가-힣][\.\)]\s+', line):
            normalized_lines.append(f"#### {line}")
            continue
        
        # 5. 소항목 (①, ②, ③ 등)
        if re.match(r'^[①②③④⑤⑥⑦⑧⑨⑩]\s+', line):
            normalized_lines.append(f"##### {line}")
            continue
        
        # 6. 중요 키워드가 포함된 줄 강조
        important_keywords = ['과실비율', '기본과실', '도로교통법', '인정기준']
        if any(keyword in line for keyword in important_keywords) and len(line) < 100:
            normalized_lines.append(f"**{line}**")
            continue
        
        # 일반 텍스트
        normalized_lines.append(line)
    
    print("✓ 제목 구조 정규화 완료")
    
    return '\n'.join(normalized_lines)

def remove_special_characters(text):
    """불필요한 특수문자 정리"""
    
    print("특수문자 정리 시작...")
    
    # PDF 변환 시 생기는 이상한 문자들 제거
    text = re.sub(r'[^\w\s가-힣ㄱ-ㅎㅏ-ㅣ\.\,\:\;\(\)\[\]\-\+\=\%\#\*\|\~\`\"\'\?\!]', ' ', text)
    
    # 연속된 특수문자 정리
    text = re.sub(r'[\.\,\:\;]{2,}', '.', text)
    
    print("✓ 특수문자 정리 완료")
    
    return text

def clean_markdown_file(file_path):
    """마크다운 파일 정제"""
    
    if not os.path.exists(file_path):
        print(f"❌ 파일을 찾을 수 없습니다: {file_path}")
        return None
    
    print(f"\n{'='*60}")
    print(f"파일 정제 시작: {os.path.basename(file_path)}")
    print(f"{'='*60}")
    
    # 파일 읽기
    with open(file_path, 'r', encoding='utf-8') as f:
        content = f.read()
    
    original_size = len(content)
    original_lines = len(content.split('\n'))
    
    print(f"원본 파일 정보:")
    print(f"  - 문자 수: {original_size:,}")
    print(f"  - 줄 수: {original_lines:,}")
    
    # 단계별 정제
    content = basic_text_cleaning(content)
    content = remove_repetitive_headers(content)
    content = normalize_headers(content)
    content = remove_special_characters(content)
    
    # 최종 정리
    content = basic_text_cleaning(content)  # 한번 더 기본 정제
    
    final_size = len(content)
    final_lines = len(content.split('\n'))
    
    print(f"\n정제 결과:")
    print(f"  - 최종 문자 수: {final_size:,} ({original_size-final_size:+,})")
    print(f"  - 최종 줄 수: {final_lines:,} ({original_lines-final_lines:+,})")
    print(f"  - 압축률: {(1-final_size/original_size)*100:.1f}%")
    
    # 정제된 파일 저장
    base_name = os.path.splitext(os.path.basename(file_path))[0]
    output_path = os.path.join(os.path.dirname(file_path), f"{base_name}_기본정제.md")
    
    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(content)
    
    print(f"✅ 정제 완료: {output_path}")
    
    return content, output_path

def preview_cleaned_content(content, num_lines=30):
    """정제된 내용 미리보기"""
    
    lines = content.split('\n')
    print(f"\n📋 정제 결과 미리보기 (처음 {num_lines}줄):")
    print("-" * 50)
    
    for i, line in enumerate(lines[:num_lines]):
        if line.strip():
            print(f"{i+1:3d}: {line}")
        else:
            print(f"{i+1:3d}: ")
    
    if len(lines) > num_lines:
        print(f"... (총 {len(lines):,}줄 중 {num_lines}줄만 표시)")

# 메인 실행
def main():
    # 파일 경로
    file1_path = r"C:\project\2stProject_jun\jun\과실비율PDF\231107_과실비율인정기준_온라인용.md"
    file2_path = r"C:\project\2stProject_jun\jun\과실비율PDF\(최종)과실비율심의사례_(54MB).md"
    
    # 두 파일 정제
    results = []
    
    for file_path in [file1_path, file2_path]:
        result = clean_markdown_file(file_path)
        if result:
            content, output_path = result
            results.append({
                'original_path': file_path,
                'output_path': output_path,
                'content': content,
                'filename': os.path.basename(output_path)
            })
            
            # 미리보기
            preview_cleaned_content(content)
    
    # 전체 결과 요약
    print(f"\n{'='*60}")
    print("전체 정제 결과 요약")
    print(f"{'='*60}")
    
    total_chars = 0
    for i, result in enumerate(results):
        char_count = len(result['content'])
        total_chars += char_count
        print(f"{i+1}. {result['filename']}")
        print(f"   - 문자 수: {char_count:,}")
        print(f"   - 저장 위치: {result['output_path']}")
    
    print(f"\n총 문자 수: {total_chars:,}")
    print(f"처리된 파일: {len(results)}개")
    
    print(f"\n다음 단계:")
    print("1. 정제 결과 확인")
    print("2. 추가 고급 정제 필요성 판단")
    print("3. 만족스러우면 통합 작업 진행")
    
    return results

# 실행
if __name__ == "__main__":
    results = main()
# Out:
# ============================================================
# 파일 정제 시작: 231107_과실비율인정기준_온라인용.md
# ============================================================
# 원본 파일 정보:
#   - 문자 수: 561,331
#   - 줄 수: 26,109
# 기본 정제 시작...
# ✓ 과도한 줄바꿈 정리 완료
# ✓ 공백 정리 완료
# ✓ 빈 줄 정리 완료
# 중복 콘텐츠 제거 시작...
# ✓ 페이지 번호 제거 완료
# ✓ 543개의 반복 줄 발견
# ✓ 중복 콘텐츠 제거 완료
# 제목 구조 정규화 시작...
# ✓ 제목 구조 정규화 완료
# 특수문자 정리 시작...
# ✓ 특수문자 정리 완료
# 기본 정제 시작...
# ✓ 과도한 줄바꿈 정리 완료
# ✓ 공백 정리 완료
# ✓ 빈 줄 정리 완료
#
# 정제 결과:
#   - 최종 문자 수: 383,892 (+177,439)
#   - 최종 줄 수: 17,653 (+8,456)
#   - 압축률: 31.6%
# ✅ 정제 완료: C:\project\2stProject_jun\jun\과실비율PDF\231107_과실비율인정기준_온라인용_기본정제.md
#
# 📋 정제 결과 미리보기 (처음 30줄):
# --------------------------------------------------
#   1: # 페이지 1
#   2:
#   3: 2023.6.
#   4: 자동차사고
#   5: **과실비율**
#   6: **인정기준**
#   7:
#   8: # 페이지 2
#   9:
#  10: **자동차사고 과실비율 인정기준**
#  11: 발간사.006
#  12: 제1편 개정경과.009
#  13: 제2편 총 설.011
#  14: ### 1. 과실비율 인정기준의 필요성.012
#  15: ### 2. 과실과 과실상계.014
#  16: (1) 과실의 의의.014
#  17: (2) 피해자 과실상계의 의의.014
#  18: (3) 피해자 과실상계의 법적 근거.015
#  19: ### 3. 과실비율 인정기준의 기본원칙.016
#  20: (1) 신뢰의 원칙 - 예견가능성.016
#  21: ### 1) 자동차 대 자동차 .016
#  22: ### 2) 자동차 대 보행자.018
#  23: (2) 과실상계의 기본조건 - 인과관계.018
#  24: ### 4. 과실비율 인정기준의 적용.020
#  25: **(1) 기본 과실비율의 일반적인 설정방법.020**
#  26: **(2) 구체적인 과실비율 확정방법(수정요소적용).020**
#  27: ### 5. 인적 손해에서의 과실상계 별도적용기준.022
#  28: (1) 별도적용기준의 정의.022
#  29: (2) 별도적용기준 유형.022
#  30: (3) 적용 원칙.022
# ... (총 17,653줄 중 30줄만 표시)
#
# ============================================================
# 파일 정제 시작: (최종)과실비율심의사례_(54MB).md
# ============================================================
# 원본 파일 정보:
#   - 문자 수: 445,586
#   - 줄 수: 19,855
# 기본 정제 시작...
# ✓ 과도한 줄바꿈 정리 완료
# ✓ 공백 정리 완료
# ✓ 빈 줄 정리 완료
# 중복 콘텐츠 제거 시작...
# ✓ 페이지 번호 제거 완료
# ✓ 370개의 반복 줄 발견
# ✓ 중복 콘텐츠 제거 완료
# 제목 구조 정규화 시작...
# ✓ 제목 구조 정규화 완료
# 특수문자 정리 시작...
# ✓ 특수문자 정리 완료
# 기본 정제 시작...
# ✓ 과도한 줄바꿈 정리 완료
# ✓ 공백 정리 완료
# ✓ 빈 줄 정리 완료
#
# 정제 결과:
#   - 최종 문자 수: 346,064 (+99,522)
#   - 최종 줄 수: 15,156 (+4,699)
#   - 압축률: 22.3%
# ✅ 정제 완료: C:\project\2stProject_jun\jun\과실비율PDF\(최종)과실비율심의사례_(54MB)_기본정제.md
#
# 📋 정제 결과 미리보기 (처음 30줄):
# --------------------------------------------------
#   1: # 페이지 1
#   2:
#   3: # 페이지 2
#   4:
#   5: **자동차사고 과실비율분쟁 심의 사례**
#   6: 발간사.011
#   7: **과실비율분쟁 심의위원회 운영현황.015**
#   8: 제1장 자동차와 자동차의 사고.019
#   9: 직진 대 직진 사고 .020
#  10: 사거리 교차로(상대 차량이 측면 방향에서 진입).020
#  11: 한쪽 차량 신호위반 사고 (기본과실).020
#  12: 한쪽 차량 신호위반 사고 (수정과실).022
#  13: (가) 교차로를 벗어나지 못한 사고(A녹색에 직진 진입 적색에 충돌) (수정과실).024
#  14: 양 차량 신호위반 사고(황색 대 적색) (기본과실).026
#  15: 양 차량 신호위반 사고(황색 대 적색) (수정과실).028
#  16: 사거리 교차로(도로폭 기준).030
#  17: **(나) 오른쪽 도로에서 직진 대 왼쪽 도로에서 직진 사고(동일폭) (B선진입) (기본과실).030**
#  18: (가) 대로 직진 대 소로 직진 사고(동시진입) (기본과실).032
#  19: (나) 대로 직진 대 소로 직진 사고(B선진입) (기본과실).034
#  20: (다) 대로 직진 대 소로 직진 사고(A선진입) (기본과실).036
#  21: 사거리 교차로(표지가 한쪽 방향에만 있음).038
#  22: 일시정지 위반 사고 (기본과실).038
#  23: 일시정지 위반 사고 (수정과실).040
#  24: 일방통행 위반 사고 (기본과실).042
#  25: 일방통행 위반 사고 (수정과실).044
#  26: 직진 대 좌회전 사고(맞은편) .046
#  27: 사거리 교차로(상대 차량이 맞은편 방향에서 진입).046
#  28: 신호위반 사고(적색신호 직진) (기본과실).046
#  29: 신호위반 사고(녹색 직진신호 좌회전) (기본과실).048
#  30: 신호위반 사고(녹색 직진신호 좌회전) (수정과실).050
# ... (총 15,156줄 중 30줄만 표시)
#
# ============================================================
# 전체 정제 결과 요약
# ============================================================
# 1. 231107_과실비율인정기준_온라인용_기본정제.md
#    - 문자 수: 383,892
#    - 저장 위치: C:\project\2stProject_jun\jun\과실비율PDF\231107_과실비율인정기준_온라인용_기본정제.md
# 2. (최종)과실비율심의사례_(54MB)_기본정제.md
#    - 문자 수: 346,064
#    - 저장 위치: C:\project\2stProject_jun\jun\과실비율PDF\(최종)과실비율심의사례_(54MB)_기본정제.md
#
# 총 문자 수: 729,956
# 처리된 파일: 2개
#
# 다음 단계:
# 1. 정제 결과 확인
# 2. 추가 고급 정제 필요성 판단
# 3. 만족스러우면 통합 작업 진행

# %% [markdown]
# # 2. 추가보완 기본정제

# %%
import re
import os

def extract_case_data_from_markdown(content):
    """마크다운에서 사례 데이터 추출"""
    
    cases = []
    lines = content.split('\n')
    current_case = None
    
    for i, line in enumerate(lines):
        line = line.strip()
        if not line:
            continue
        
        # 사례 코드 패턴 감지 (보1, 차1, 교1 등)
        case_pattern = r'^([가-힣]+)(\d+)\s*[:：]\s*(.+)'
        if re.match(case_pattern, line):
            # 이전 사례 저장
            if current_case:
                cases.append(current_case)
            
            match = re.match(case_pattern, line)
            case_type = match.group(1)
            case_number = match.group(2)
            case_description = match.group(3)
            
            current_case = {
                'code': f"{case_type}{case_number}",
                'type': case_type,
                'number': case_number,
                'title': case_description,
                'participants': {},
                'basic_fault_ratio': None,
                'adjustments': [],
                'non_applicable': []
            }
            continue
        
        if not current_case:
            continue
        
        # 참여자 정보 ((보), (차) 등)
        participant_pattern = r'^\(([가-힣]+)\)\s*(.+)'
        if re.match(participant_pattern, line):
            match = re.match(participant_pattern, line)
            participant = match.group(1)
            description = match.group(2)
            current_case['participants'][participant] = description
            continue
        
        # 기본 과실비율
        fault_patterns = [
            r'([가-힣]+)\s*기본\s*과실비율?\s*[:：]\s*(\d+)',
            r'기본\s*과실\s*[:：]\s*(.+)',
            r'과실비율?\s*[:：]\s*(\d+)\s*[:：]\s*(\d+)'
        ]
        
        for pattern in fault_patterns:
            if re.search(pattern, line):
                current_case['basic_fault_ratio'] = line
                break
        
        # 조정 요소 (①, ②, +5, -10 등)
        # 숫자나 기호로 시작하는 조정 항목들
        adjustment_pattern = r'([①②③④⑤⑥⑦⑧⑨⑩\d]+\.?)\s*(.+?)(?:\s+([+\-]\d+)|(\+\d+|\-\d+))'
        if re.search(adjustment_pattern, line):
            match = re.search(adjustment_pattern, line)
            number = match.group(1)
            description = match.group(2).strip()
            value = match.group(3) or match.group(4)
            
            current_case['adjustments'].append({
                'number': number,
                'description': description,
                'value': value
            })
            continue
        
        # 비적용 항목
        if '비적용' in line:
            description = line.replace('비적용', '').strip()
            current_case['non_applicable'].append(description)
            continue
        
        # 단순 조정 항목 (들여쓰기로 된 세부 항목들)
        if line.startswith('    ') or line.startswith('\t'):
            clean_line = line.strip()
            # +숫자 또는 -숫자가 포함된 경우
            value_pattern = r'(.+?)\s*([+\-]\d+)(?:\s|$)'
            match = re.search(value_pattern, clean_line)
            if match:
                description = match.group(1).strip()
                value = match.group(2)
                current_case['adjustments'].append({
                    'number': '',
                    'description': description,
                    'value': value
                })
    
    # 마지막 사례 저장
    if current_case:
        cases.append(current_case)
    
    return cases

def format_case_as_table_markdown(case):
    """사례를 표 형태 마크다운으로 변환"""
    
    markdown = []
    
    # 제목
    markdown.append(f"## {case['code']}: {case['title']}")
    markdown.append("")
    
    # 참여자 정보
    if case['participants']:
        for participant, description in case['participants'].items():
            markdown.append(f"**({participant})** {description}")
        markdown.append("")
    
    # 기본 과실비율
    if case['basic_fault_ratio']:
        markdown.append(f"**기본 과실비율**: {case['basic_fault_ratio']}")
        markdown.append("")
    
    # 조정 요소 표
    if case['adjustments'] or case['non_applicable']:
        markdown.append("### 과실비율 조정요소")
        markdown.append("")
        markdown.append("| 항목 | 조정 내용 | 조정값 |")
        markdown.append("|------|-----------|--------|")
        
        # 조정 요소
        for adj in case['adjustments']:
            number = adj['number'] if adj['number'] else ''
            description = adj['description']
            value = adj['value'] if adj['value'] else ''
            markdown.append(f"| {number} | {description} | {value} |")
        
        # 비적용 항목
        for non_app in case['non_applicable']:
            markdown.append(f"| | {non_app} | 비적용 |")
        
        markdown.append("")
    
    markdown.append("---")
    markdown.append("")
    
    return '\n'.join(markdown)

def clean_and_restructure_markdown(content):
    """마크다운 내용을 깨끗하게 정제하고 표 구조로 재구성"""
    
    # 기본 텍스트 정제
    content = basic_text_cleaning(content)
    
    # 사례 데이터 추출
    cases = extract_case_data_from_markdown(content)
    
    # 표 형태로 재구성
    restructured_content = []
    
    # 문서 헤더
    restructured_content.append("# 자동차 사고 과실비율 인정기준")
    restructured_content.append("")
    restructured_content.append(f"총 {len(cases)}개 사례")
    restructured_content.append("")
    restructured_content.append("---")
    restructured_content.append("")
    
    # 각 사례를 표 형태로 변환
    for case in cases:
        case_markdown = format_case_as_table_markdown(case)
        restructured_content.append(case_markdown)
    
    return '\n'.join(restructured_content)

def basic_text_cleaning(text):
    """기본적인 텍스트 정제"""
    
    # 과도한 줄바꿈 정리
    text = re.sub(r'\n\s*\n\s*\n+', '\n\n', text)
    
    # 각 줄의 앞뒤 공백 제거
    lines = text.split('\n')
    cleaned_lines = []
    
    for line in lines:
        line = line.strip()
        # 과도한 중간 공백 정리
        line = re.sub(r'\s{2,}', ' ', line)
        # 탭을 공백으로 변환
        line = line.replace('\t', ' ')
        cleaned_lines.append(line)
    
    # 연속된 빈 줄 정리
    final_lines = []
    prev_empty = False
    
    for line in cleaned_lines:
        if line == "":
            if not prev_empty:
                final_lines.append(line)
            prev_empty = True
        else:
            final_lines.append(line)
            prev_empty = False
    
    return '\n'.join(final_lines)

def process_markdown_file(file_path):
    """마크다운 파일을 표 구조로 정제"""
    
    if not os.path.exists(file_path):
        print(f"❌ 파일을 찾을 수 없습니다: {file_path}")
        return None
    
    print(f"📄 파일 처리 시작: {os.path.basename(file_path)}")
    
    # 파일 읽기
    with open(file_path, 'r', encoding='utf-8') as f:
        content = f.read()
    
    original_size = len(content)
    original_lines = len(content.split('\n'))
    
    print(f"  📊 원본 정보: {original_size:,} 문자, {original_lines:,} 줄")
    
    # 정제 및 재구성
    restructured_content = clean_and_restructure_markdown(content)
    
    final_size = len(restructured_content)
    final_lines = len(restructured_content.split('\n'))
    
    print(f"  ✅ 정제 완료: {final_size:,} 문자, {final_lines:,} 줄")
    
    # 정제된 파일 저장
    base_name = os.path.splitext(os.path.basename(file_path))[0]
    output_path = os.path.join(os.path.dirname(file_path), f"{base_name}_표정제.md")
    
    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(restructured_content)
    
    print(f"  💾 저장 완료: {output_path}")
    
    return restructured_content, output_path

def preview_restructured_content(content, num_lines=50):
    """정제된 내용 미리보기"""
    
    lines = content.split('\n')
    print(f"\n📋 정제 결과 미리보기 (처음 {num_lines}줄):")
    print("=" * 60)
    
    for i, line in enumerate(lines[:num_lines]):
        print(f"{i+1:3d}: {line}")
    
    if len(lines) > num_lines:
        print(f"... (총 {len(lines):,}줄 중 {num_lines}줄만 표시)")

def main():
    """메인 실행 함수"""
    
    # 파일 경로
    file_paths = [
        r"C:\project\2stProject_jun\jun\과실비율PDF\추출 마크다운\231107_과실비율인정기준_온라인용.md",
        r"C:\project\2stProject_jun\jun\과실비율PDF\추출 마크다운\(최종)과실비율심의사례_(54MB).md"
    ]
    
    results = []
    
    print("🚀 마크다운 표 구조 정제 시작")
    print("=" * 60)
    
    for file_path in file_paths:
        result = process_markdown_file(file_path)
        if result:
            content, output_path = result
            results.append({
                'original_path': file_path,
                'output_path': output_path,
                'content': content,
                'filename': os.path.basename(output_path)
            })
            
            # 미리보기
            preview_restructured_content(content)
            print("\n" + "="*60 + "\n")
    
    # 전체 결과 요약
    print("📊 전체 정제 결과 요약")
    print("=" * 60)
    
    total_chars = 0
    for i, result in enumerate(results):
        char_count = len(result['content'])
        total_chars += char_count
        print(f"{i+1}. {result['filename']}")
        print(f"   📄 문자 수: {char_count:,}")
        print(f"   💾 저장 위치: {result['output_path']}")
        print()
    
    print(f"📈 총 문자 수: {total_chars:,}")
    print(f"📁 처리된 파일: {len(results)}개")
    
    print("\n🎯 다음 단계:")
    print("1. 정제된 표 구조 확인")
    print("2. 필요시 추가 조정")
    print("3. DOCS 통합 변환 진행")
    
    return results

# 실행
if __name__ == "__main__":
    results = main()
# Out:
# 🚀 마크다운 표 구조 정제 시작
# ============================================================
# 📄 파일 처리 시작: 231107_과실비율인정기준_온라인용.md
#   📊 원본 정보: 561,331 문자, 26,109 줄
#   ✅ 정제 완료: 33 문자, 6 줄
#   💾 저장 완료: C:\project\2stProject_jun\jun\과실비율PDF\추출 마크다운\231107_과실비율인정기준_온라인용_표정제.md
#
# 📋 정제 결과 미리보기 (처음 50줄):
# ============================================================
#   1: # 자동차 사고 과실비율 인정기준
#   2:
#   3: 총 0개 사례
#   4:
#   5: ---
#   6:
#
# ============================================================
#
# 📄 파일 처리 시작: (최종)과실비율심의사례_(54MB).md
#   📊 원본 정보: 445,586 문자, 19,855 줄
#   ✅ 정제 완료: 33 문자, 6 줄
#   💾 저장 완료: C:\project\2stProject_jun\jun\과실비율PDF\추출 마크다운\(최종)과실비율심의사례_(54MB)_표정제.md
#
# 📋 정제 결과 미리보기 (처음 50줄):
# ============================================================
#   1: # 자동차 사고 과실비율 인정기준
#   2:
#   3: 총 0개 사례
#   4:
#   5: ---
#   6:
#
# ============================================================
#
# 📊 전체 정제 결과 요약
# ============================================================
# 1. 231107_과실비율인정기준_온라인용_표정제.md
#    📄 문자 수: 33
#    💾 저장 위치: C:\project\2stProject_jun\jun\과실비율PDF\추출 마크다운\231107_과실비율인정기준_온라인용_표정제.md
#
# 2. (최종)과실비율심의사례_(54MB)_표정제.md
#    📄 문자 수: 33
#    💾 저장 위치: C:\project\2stProject_jun\jun\과실비율PDF\추출 마크다운\(최종)과실비율심의사례_(54MB)_표정제.md
#
# 📈 총 문자 수: 66
# 📁 처리된 파일: 2개
#
# 🎯 다음 단계:
# 1. 정제된 표 구조 확인
# 2. 필요시 추가 조정
# 3. DOCS 통합 변환 진행

# %% [markdown]
# # 3. 마크다운 표정제

# %%
import fitz  # PyMuPDF
import re
import os

def extract_and_structure_from_pdf(pdf_path):
    """PDF에서 바로 표 구조로 정제된 마크다운 생성"""
    
    if not os.path.exists(pdf_path):
        print(f"❌ 파일을 찾을 수 없습니다: {pdf_path}")
        return None
    
    print(f"📄 PDF 처리 시작: {os.path.basename(pdf_path)}")
    
    doc = fitz.open(pdf_path)
    cases = []
    raw_text = ""
    
    # 전체 텍스트 추출
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        text = page.get_text()
        raw_text += text + "\n"
        print(f"  📄 페이지 {page_num + 1}/{len(doc)} 추출 완료")
    
    doc.close()
    
    print(f"  📊 총 추출 텍스트: {len(raw_text):,} 문자")
    
    # 텍스트에서 사례 추출
    cases = extract_cases_from_text(raw_text)
    
    print(f"  🔍 추출된 사례 수: {len(cases)}")
    
    # 표 형태 마크다운 생성
    structured_markdown = create_table_markdown(cases, os.path.basename(pdf_path))
    
    return structured_markdown, cases

def extract_cases_from_text(text):
    """텍스트에서 사례 데이터 추출"""
    
    cases = []
    lines = text.split('\n')
    current_case = None
    
    for i, line in enumerate(lines):
        line = line.strip()
        if not line:
            continue
        
        # 사례 코드 패턴 (보1, 차1, 교1 등)
        case_patterns = [
            r'^([보차교가나다라마바사아자차카타파하])\s*(\d+)\s*[:：]\s*(.+)',
            r'^([보차교가나다라마바사아자차카타파하])(\d+)\s+(.+)',
            r'^(\d+)\.\s*([보차교].+?)[:：]\s*(.+)'
        ]
        
        for pattern in case_patterns:
            match = re.match(pattern, line)
            if match:
                if current_case:
                    cases.append(current_case)
                
                if pattern == case_patterns[2]:  # 숫자로 시작하는 패턴
                    case_code = f"{match.group(2)[:1]}{match.group(1)}"
                    case_title = match.group(3)
                else:
                    case_code = f"{match.group(1)}{match.group(2)}"
                    case_title = match.group(3)
                
                current_case = {
                    'code': case_code,
                    'title': case_title,
                    'participants': {},
                    'basic_fault_ratio': None,
                    'fault_details': {},
                    'adjustments': [],
                    'special_conditions': []
                }
                break
        
        if not current_case:
            continue
        
        # 참여자 정보 ((보), (차) 등)
        participant_pattern = r'^\(([보차가나다라마바사아자차카타파하])\)\s*(.+)'
        if re.match(participant_pattern, line):
            match = re.match(participant_pattern, line)
            participant = match.group(1)
            description = match.group(2)
            current_case['participants'][participant] = description
            continue
        
        # 기본 과실비율 패턴들
        fault_patterns = [
            r'([보차가나다라마바사아자차카타파하])\s*(?:기본\s*)?과실비율?\s*[:：]\s*(\d+)',
            r'기본\s*과실\s*[:：]\s*([보차]\s*\d+%?\s*[:：]\s*[보차]\s*\d+%?)',
            r'과실비율?\s*[:：]\s*(\d+)\s*[:：]\s*(\d+)',
            r'([보차])\s*(\d+)%?\s*[:：]\s*([보차])\s*(\d+)%?'
        ]
        
        for pattern in fault_patterns:
            match = re.search(pattern, line)
            if match:
                if pattern == fault_patterns[0]:  # 단일 참여자
                    participant = match.group(1)
                    ratio = match.group(2)
                    current_case['fault_details'][participant] = ratio
                elif pattern == fault_patterns[3]:  # 두 참여자
                    p1, r1, p2, r2 = match.groups()
                    current_case['fault_details'][p1] = r1
                    current_case['fault_details'][p2] = r2
                else:
                    current_case['basic_fault_ratio'] = line
                break
        
        # 조정 요소들 (①, ②, +5, -10 등)
        adjustment_patterns = [
            r'([①②③④⑤⑥⑦⑧⑨⑩])\s*(.+?)\s*([+\-]\d+)',
            r'(.+?)\s*([+\-]\d+)(?:\s|$)',
            r'^[\s]*([가-힣\s,]+)\s*([+\-]\d+)$'
        ]
        
        for pattern in adjustment_patterns:
            match = re.search(pattern, line)
            if match:
                if pattern == adjustment_patterns[0]:
                    number = match.group(1)
                    description = match.group(2).strip()
                    value = match.group(3)
                else:
                    number = ''
                    description = match.group(1).strip()
                    value = match.group(2)
                
                # 중복 확인
                exists = any(adj['description'] == description for adj in current_case['adjustments'])
                if not exists and description:
                    current_case['adjustments'].append({
                        'number': number,
                        'description': description,
                        'value': value
                    })
                break
        
        # 비적용 항목
        if '비적용' in line:
            description = re.sub(r'비적용', '', line).strip()
            if description:
                current_case['special_conditions'].append({
                    'type': '비적용',
                    'description': description
                })
        
        # 도로교통법 참조
        law_match = re.search(r'도로교통법\s*제?\s*(\d+)\s*조', line)
        if law_match:
            law_ref = f"도로교통법 제{law_match.group(1)}조"
            if 'related_laws' not in current_case:
                current_case['related_laws'] = []
            if law_ref not in current_case['related_laws']:
                current_case['related_laws'].append(law_ref)
    
    # 마지막 사례 추가
    if current_case:
        cases.append(current_case)
    
    return cases

def create_table_markdown(cases, filename):
    """사례들을 표 형태 마크다운으로 변환"""
    
    markdown_lines = []
    
    # 문서 헤더
    doc_title = os.path.splitext(filename)[0]
    markdown_lines.append(f"# {doc_title}")
    markdown_lines.append("")
    markdown_lines.append(f"📊 **총 {len(cases)}개 사례**")
    markdown_lines.append("")
    markdown_lines.append("---")
    markdown_lines.append("")
    
    # 각 사례를 표 형태로 변환
    for case in cases:
        # 사례 제목
        markdown_lines.append(f"## {case['code']}: {case['title']}")
        markdown_lines.append("")
        
        # 참여자 정보
        if case['participants']:
            markdown_lines.append("### 📋 상황 설명")
            markdown_lines.append("")
            for participant, description in case['participants'].items():
                markdown_lines.append(f"- **({participant})** {description}")
            markdown_lines.append("")
        
        # 기본 과실비율
        if case['basic_fault_ratio'] or case['fault_details']:
            markdown_lines.append("### ⚖️ 기본 과실비율")
            markdown_lines.append("")
            
            if case['fault_details']:
                for participant, ratio in case['fault_details'].items():
                    markdown_lines.append(f"- **{participant}**: {ratio}%")
            elif case['basic_fault_ratio']:
                markdown_lines.append(f"- {case['basic_fault_ratio']}")
            
            markdown_lines.append("")
        
        # 조정 요소 표
        if case['adjustments'] or case['special_conditions']:
            markdown_lines.append("### 📊 과실비율 조정요소")
            markdown_lines.append("")
            markdown_lines.append("| 구분 | 조정 내용 | 조정값 |")
            markdown_lines.append("|------|-----------|--------|")
            
            # 일반 조정 요소
            for adj in case['adjustments']:
                number = adj['number'] if adj['number'] else ''
                description = adj['description']
                value = adj['value']
                markdown_lines.append(f"| {number} | {description} | {value} |")
            
            # 특수 조건 (비적용 등)
            for condition in case['special_conditions']:
                desc = condition['description']
                ctype = condition['type']
                markdown_lines.append(f"| | {desc} | {ctype} |")
            
            markdown_lines.append("")
        
        # 관련 법령
        if 'related_laws' in case and case['related_laws']:
            markdown_lines.append("### 📜 관련 법령")
            markdown_lines.append("")
            for law in case['related_laws']:
                markdown_lines.append(f"- {law}")
            markdown_lines.append("")
        
        # 구분선
        markdown_lines.append("---")
        markdown_lines.append("")
    
    return '\n'.join(markdown_lines)

def process_pdf_to_table_markdown(pdf_path):
    """PDF를 표 구조 마크다운으로 변환"""
    
    result = extract_and_structure_from_pdf(pdf_path)
    if not result:
        return None
    
    structured_markdown, cases = result
    
    # 출력 파일 경로
    base_name = os.path.splitext(os.path.basename(pdf_path))[0]
    output_path = os.path.join(os.path.dirname(pdf_path), f"{base_name}_표정제.md")
    
    # 파일 저장
    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(structured_markdown)
    
    print(f"  ✅ 표 정제 완료: {output_path}")
    print(f"  📄 생성된 문서 크기: {len(structured_markdown):,} 문자")
    
    return structured_markdown, output_path, cases

def preview_table_markdown(content, num_lines=50):
    """생성된 표 마크다운 미리보기"""
    
    lines = content.split('\n')
    print(f"\n📋 표 정제 결과 미리보기 (처음 {num_lines}줄):")
    print("=" * 70)
    
    for i, line in enumerate(lines[:num_lines]):
        print(f"{i+1:3d}: {line}")
    
    if len(lines) > num_lines:
        print(f"... (총 {len(lines):,}줄 중 {num_lines}줄만 표시)")

def main():
    """메인 실행 함수"""
    
    # PDF 파일 경로
    pdf_files = [
        r"C:\project\2stProject_jun\jun\과실비율PDF\과실비율 원본 PDF\231107_과실비율인정기준_온라인용.pdf",
        r"C:\project\2stProject_jun\jun\과실비율PDF\과실비율 원본 PDF\(최종)과실비율심의사례_(54MB).pdf"
    ]
    
    results = []
    
    print("🚀 PDF → 표 구조 마크다운 변환 시작")
    print("=" * 70)
    
    for pdf_path in pdf_files:
        print(f"\n📂 처리 대상: {os.path.basename(pdf_path)}")
        
        result = process_pdf_to_table_markdown(pdf_path)
        if result:
            content, output_path, cases = result
            results.append({
                'pdf_path': pdf_path,
                'output_path': output_path,
                'content': content,
                'cases': cases,
                'filename': os.path.basename(output_path)
            })
            
            # 미리보기
            preview_table_markdown(content)
            print("\n" + "="*70)
    
    # 전체 결과 요약
    print("\n📊 전체 변환 결과 요약")
    print("=" * 70)
    
    total_cases = 0
    total_chars = 0
    
    for i, result in enumerate(results):
        case_count = len(result['cases'])
        char_count = len(result['content'])
        total_cases += case_count
        total_chars += char_count
        
        print(f"{i+1}. {result['filename']}")
        print(f"   📄 추출된 사례: {case_count}개")
        print(f"   📝 문서 크기: {char_count:,} 문자")
        print(f"   💾 저장 위치: {result['output_path']}")
        print()
    
    print(f"📈 총 사례 수: {total_cases}개")
    print(f"📄 총 문서 크기: {total_chars:,} 문자")
    print(f"📁 생성된 파일: {len(results)}개")
    
    print("\n🎯 다음 단계:")
    print("1. 생성된 표 구조 마크다운 확인")
    print("2. 필요시 조정 및 수정")
    print("3. DOCS 통합 변환 또는 RAG 데이터셋 생성")
    
    return results

# 실행
if __name__ == "__main__":
    results = main()
# Out:
# 🚀 PDF → 표 구조 마크다운 변환 시작
# ======================================================================
#
# 📂 처리 대상: 231107_과실비율인정기준_온라인용.pdf
# 📄 PDF 처리 시작: 231107_과실비율인정기준_온라인용.pdf
#   📄 페이지 1/600 추출 완료
#   📄 페이지 2/600 추출 완료
#   📄 페이지 3/600 추출 완료
#   📄 페이지 4/600 추출 완료
#   📄 페이지 5/600 추출 완료
#   📄 페이지 6/600 추출 완료
#   📄 페이지 7/600 추출 완료
#   📄 페이지 8/600 추출 완료
#   📄 페이지 9/600 추출 완료
#   📄 페이지 10/600 추출 완료
#   📄 페이지 11/600 추출 완료
#   📄 페이지 12/600 추출 완료
#   📄 페이지 13/600 추출 완료
#   📄 페이지 14/600 추출 완료
#   📄 페이지 15/600 추출 완료
#   📄 페이지 16/600 추출 완료
#   📄 페이지 17/600 추출 완료
#   📄 페이지 18/600 추출 완료
#   📄 페이지 19/600 추출 완료
#   📄 페이지 20/600 추출 완료
#   📄 페이지 21/600 추출 완료
#   📄 페이지 22/600 추출 완료
#   📄 페이지 23/600 추출 완료
#   📄 페이지 24/600 추출 완료
#   📄 페이지 25/600 추출 완료
#   📄 페이지 26/600 추출 완료
#   📄 페이지 27/600 추출 완료
#   📄 페이지 28/600 추출 완료
#   📄 페이지 29/600 추출 완료
#   📄 페이지 30/600 추출 완료
#   📄 페이지 31/600 추출 완료
#   📄 페이지 32/600 추출 완료
#   📄 페이지 33/600 추출 완료
#   📄 페이지 34/600 추출 완료
#   📄 페이지 35/600 추출 완료
#   📄 페이지 36/600 추출 완료
#   📄 페이지 37/600 추출 완료
#   📄 페이지 38/600 추출 완료
#   📄 페이지 39/600 추출 완료
#   📄 페이지 40/600 추출 완료
#   📄 페이지 41/600 추출 완료
#   📄 페이지 42/600 추출 완료
#   📄 페이지 43/600 추출 완료
#   📄 페이지 44/600 추출 완료
#   📄 페이지 45/600 추출 완료
#   📄 페이지 46/600 추출 완료
#   📄 페이지 47/600 추출 완료
#   📄 페이지 48/600 추출 완료
#   📄 페이지 49/600 추출 완료
#   📄 페이지 50/600 추출 완료
#   📄 페이지 51/600 추출 완료
#   📄 페이지 52/600 추출 완료
#   📄 페이지 53/600 추출 완료
#   📄 페이지 54/600 추출 완료
#   📄 페이지 55/600 추출 완료
#   📄 페이지 56/600 추출 완료
#   📄 페이지 57/600 추출 완료
#   📄 페이지 58/600 추출 완료
#   📄 페이지 59/600 추출 완료
#   📄 페이지 60/600 추출 완료
#   📄 페이지 61/600 추출 완료
#   📄 페이지 62/600 추출 완료
#   📄 페이지 63/600 추출 완료
#   📄 페이지 64/600 추출 완료
#   📄 페이지 65/600 추출 완료
#   📄 페이지 66/600 추출 완료
#   📄 페이지 67/600 추출 완료
#   📄 페이지 68/600 추출 완료
#   📄 페이지 69/600 추출 완료
#   📄 페이지 70/600 추출 완료
#   📄 페이지 71/600 추출 완료
#   📄 페이지 72/600 추출 완료
#   📄 페이지 73/600 추출 완료
#   📄 페이지 74/600 추출 완료
#   📄 페이지 75/600 추출 완료
#   📄 페이지 76/600 추출 완료
#   📄 페이지 77/600 추출 완료
#   📄 페이지 78/600 추출 완료
#   📄 페이지 79/600 추출 완료
#   📄 페이지 80/600 추출 완료
#   📄 페이지 81/600 추출 완료
#   📄 페이지 82/600 추출 완료
#   📄 페이지 83/600 추출 완료
#   📄 페이지 84/600 추출 완료
#   📄 페이지 85/600 추출 완료
#   📄 페이지 86/600 추출 완료
#   📄 페이지 87/600 추출 완료
#   📄 페이지 88/600 추출 완료
#   📄 페이지 89/600 추출 완료
#   📄 페이지 90/600 추출 완료
#   📄 페이지 91/600 추출 완료
#   📄 페이지 92/600 추출 완료
#   📄 페이지 93/600 추출 완료
#   📄 페이지 94/600 추출 완료
#   📄 페이지 95/600 추출 완료
#   📄 페이지 96/600 추출 완료
#   📄 페이지 97/600 추출 완료
#   📄 페이지 98/600 추출 완료
#   📄 페이지 99/600 추출 완료
#   📄 페이지 100/600 추출 완료
#   📄 페이지 101/600 추출 완료
#   📄 페이지 102/600 추출 완료
#   📄 페이지 103/600 추출 완료
#   📄 페이지 104/600 추출 완료
#   📄 페이지 105/600 추출 완료
#   📄 페이지 106/600 추출 완료
#   📄 페이지 107/600 추출 완료
#   📄 페이지 108/600 추출 완료
#   📄 페이지 109/600 추출 완료
#   📄 페이지 110/600 추출 완료
#   📄 페이지 111/600 추출 완료
#   📄 페이지 112/600 추출 완료
#   📄 페이지 113/600 추출 완료
#   📄 페이지 114/600 추출 완료
#   📄 페이지 115/600 추출 완료
#   📄 페이지 116/600 추출 완료
#   📄 페이지 117/600 추출 완료
#   📄 페이지 118/600 추출 완료
#   📄 페이지 119/600 추출 완료
#   📄 페이지 120/600 추출 완료
#   📄 페이지 121/600 추출 완료
#   📄 페이지 122/600 추출 완료
#   📄 페이지 123/600 추출 완료
#   📄 페이지 124/600 추출 완료
#   📄 페이지 125/600 추출 완료
#   📄 페이지 126/600 추출 완료
#   📄 페이지 127/600 추출 완료
#   📄 페이지 128/600 추출 완료
#   📄 페이지 129/600 추출 완료
#   📄 페이지 130/600 추출 완료
#   📄 페이지 131/600 추출 완료
#   📄 페이지 132/600 추출 완료
#   📄 페이지 133/600 추출 완료
#   📄 페이지 134/600 추출 완료
#   📄 페이지 135/600 추출 완료
#   📄 페이지 136/600 추출 완료
#   📄 페이지 137/600 추출 완료
#   📄 페이지 138/600 추출 완료
#   📄 페이지 139/600 추출 완료
#   📄 페이지 140/600 추출 완료
#   📄 페이지 141/600 추출 완료
#   📄 페이지 142/600 추출 완료
#   📄 페이지 143/600 추출 완료
#   📄 페이지 144/600 추출 완료
#   📄 페이지 145/600 추출 완료
#   📄 페이지 146/600 추출 완료
#   📄 페이지 147/600 추출 완료
#   📄 페이지 148/600 추출 완료
#   📄 페이지 149/600 추출 완료
#   📄 페이지 150/600 추출 완료
#   📄 페이지 151/600 추출 완료
#   📄 페이지 152/600 추출 완료
#   📄 페이지 153/600 추출 완료
#   📄 페이지 154/600 추출 완료
#   📄 페이지 155/600 추출 완료
#   📄 페이지 156/600 추출 완료
#   📄 페이지 157/600 추출 완료
#   📄 페이지 158/600 추출 완료
#   📄 페이지 159/600 추출 완료
#   📄 페이지 160/600 추출 완료
#   📄 페이지 161/600 추출 완료
#   📄 페이지 162/600 추출 완료
#   📄 페이지 163/600 추출 완료
#   📄 페이지 164/600 추출 완료
#   📄 페이지 165/600 추출 완료
#   📄 페이지 166/600 추출 완료
#   📄 페이지 167/600 추출 완료
#   📄 페이지 168/600 추출 완료
#   📄 페이지 169/600 추출 완료
#   📄 페이지 170/600 추출 완료
#   📄 페이지 171/600 추출 완료
#   📄 페이지 172/600 추출 완료
#   📄 페이지 173/600 추출 완료
#   📄 페이지 174/600 추출 완료
#   📄 페이지 175/600 추출 완료
#   📄 페이지 176/600 추출 완료
#   📄 페이지 177/600 추출 완료
#   📄 페이지 178/600 추출 완료
#   📄 페이지 179/600 추출 완료
#   📄 페이지 180/600 추출 완료
#   📄 페이지 181/600 추출 완료
#   📄 페이지 182/600 추출 완료
#   📄 페이지 183/600 추출 완료
#   📄 페이지 184/600 추출 완료
#   📄 페이지 185/600 추출 완료
#   📄 페이지 186/600 추출 완료
#   📄 페이지 187/600 추출 완료
#   📄 페이지 188/600 추출 완료
#   📄 페이지 189/600 추출 완료
#   📄 페이지 190/600 추출 완료
#   📄 페이지 191/600 추출 완료
#   📄 페이지 192/600 추출 완료
#   📄 페이지 193/600 추출 완료
#   📄 페이지 194/600 추출 완료
#   📄 페이지 195/600 추출 완료
#   📄 페이지 196/600 추출 완료
#   📄 페이지 197/600 추출 완료
#   📄 페이지 198/600 추출 완료
#   📄 페이지 199/600 추출 완료
#   📄 페이지 200/600 추출 완료
#   📄 페이지 201/600 추출 완료
#   📄 페이지 202/600 추출 완료
#   📄 페이지 203/600 추출 완료
#   📄 페이지 204/600 추출 완료
#   📄 페이지 205/600 추출 완료
#   📄 페이지 206/600 추출 완료
#   📄 페이지 207/600 추출 완료
#   📄 페이지 208/600 추출 완료
#   📄 페이지 209/600 추출 완료
#   📄 페이지 210/600 추출 완료
#   📄 페이지 211/600 추출 완료
#   📄 페이지 212/600 추출 완료
#   📄 페이지 213/600 추출 완료
#   📄 페이지 214/600 추출 완료
#   📄 페이지 215/600 추출 완료
#   📄 페이지 216/600 추출 완료
#   📄 페이지 217/600 추출 완료
#   📄 페이지 218/600 추출 완료
#   📄 페이지 219/600 추출 완료
#   📄 페이지 220/600 추출 완료
#   📄 페이지 221/600 추출 완료
#   📄 페이지 222/600 추출 완료
#   📄 페이지 223/600 추출 완료
#   📄 페이지 224/600 추출 완료
#   📄 페이지 225/600 추출 완료
#   📄 페이지 226/600 추출 완료
#   📄 페이지 227/600 추출 완료
#   📄 페이지 228/600 추출 완료
#   📄 페이지 229/600 추출 완료
#   📄 페이지 230/600 추출 완료
#   📄 페이지 231/600 추출 완료
#   📄 페이지 232/600 추출 완료
#   📄 페이지 233/600 추출 완료
#   📄 페이지 234/600 추출 완료
#   📄 페이지 235/600 추출 완료
#   📄 페이지 236/600 추출 완료
#   📄 페이지 237/600 추출 완료
#   📄 페이지 238/600 추출 완료
#   📄 페이지 239/600 추출 완료
#   📄 페이지 240/600 추출 완료
#   📄 페이지 241/600 추출 완료
#   📄 페이지 242/600 추출 완료
#   📄 페이지 243/600 추출 완료
#   📄 페이지 244/600 추출 완료
#   📄 페이지 245/600 추출 완료
#   📄 페이지 246/600 추출 완료
#   📄 페이지 247/600 추출 완료
#   📄 페이지 248/600 추출 완료
#   📄 페이지 249/600 추출 완료
#   📄 페이지 250/600 추출 완료
#   📄 페이지 251/600 추출 완료
#   📄 페이지 252/600 추출 완료
#   📄 페이지 253/600 추출 완료
#   📄 페이지 254/600 추출 완료
#   📄 페이지 255/600 추출 완료
#   📄 페이지 256/600 추출 완료
#   📄 페이지 257/600 추출 완료
#   📄 페이지 258/600 추출 완료
#   📄 페이지 259/600 추출 완료
#   📄 페이지 260/600 추출 완료
#   📄 페이지 261/600 추출 완료
#   📄 페이지 262/600 추출 완료
#   📄 페이지 263/600 추출 완료
#   📄 페이지 264/600 추출 완료
#   📄 페이지 265/600 추출 완료
#   📄 페이지 266/600 추출 완료
#   📄 페이지 267/600 추출 완료
#   📄 페이지 268/600 추출 완료
#   📄 페이지 269/600 추출 완료
#   📄 페이지 270/600 추출 완료
#   📄 페이지 271/600 추출 완료
#   📄 페이지 272/600 추출 완료
#   📄 페이지 273/600 추출 완료
#   📄 페이지 274/600 추출 완료
#   📄 페이지 275/600 추출 완료
#   📄 페이지 276/600 추출 완료
#   📄 페이지 277/600 추출 완료
#   📄 페이지 278/600 추출 완료
#   📄 페이지 279/600 추출 완료
#   📄 페이지 280/600 추출 완료
#   📄 페이지 281/600 추출 완료
#   📄 페이지 282/600 추출 완료
#   📄 페이지 283/600 추출 완료
#   📄 페이지 284/600 추출 완료
#   📄 페이지 285/600 추출 완료
#   📄 페이지 286/600 추출 완료
#   📄 페이지 287/600 추출 완료
#   📄 페이지 288/600 추출 완료
#   📄 페이지 289/600 추출 완료
#   📄 페이지 290/600 추출 완료
#   📄 페이지 291/600 추출 완료
#   📄 페이지 292/600 추출 완료
#   📄 페이지 293/600 추출 완료
#   📄 페이지 294/600 추출 완료
#   📄 페이지 295/600 추출 완료
#   📄 페이지 296/600 추출 완료
#   📄 페이지 297/600 추출 완료
#   📄 페이지 298/600 추출 완료
#   📄 페이지 299/600 추출 완료
#   📄 페이지 300/600 추출 완료
#   📄 페이지 301/600 추출 완료
#   📄 페이지 302/600 추출 완료
#   📄 페이지 303/600 추출 완료
#   📄 페이지 304/600 추출 완료
#   📄 페이지 305/600 추출 완료
#   📄 페이지 306/600 추출 완료
#   📄 페이지 307/600 추출 완료
#   📄 페이지 308/600 추출 완료
#   📄 페이지 309/600 추출 완료
#   📄 페이지 310/600 추출 완료
#   📄 페이지 311/600 추출 완료
#   📄 페이지 312/600 추출 완료
#   📄 페이지 313/600 추출 완료
#   📄 페이지 314/600 추출 완료
#   📄 페이지 315/600 추출 완료
#   📄 페이지 316/600 추출 완료
#   📄 페이지 317/600 추출 완료
#   📄 페이지 318/600 추출 완료
#   📄 페이지 319/600 추출 완료
#   📄 페이지 320/600 추출 완료
#   📄 페이지 321/600 추출 완료
#   📄 페이지 322/600 추출 완료
#   📄 페이지 323/600 추출 완료
#   📄 페이지 324/600 추출 완료
#   📄 페이지 325/600 추출 완료
#   📄 페이지 326/600 추출 완료
#   📄 페이지 327/600 추출 완료
#   📄 페이지 328/600 추출 완료
#   📄 페이지 329/600 추출 완료
#   📄 페이지 330/600 추출 완료
#   📄 페이지 331/600 추출 완료
#   📄 페이지 332/600 추출 완료
#   📄 페이지 333/600 추출 완료
#   📄 페이지 334/600 추출 완료
#   📄 페이지 335/600 추출 완료
#   📄 페이지 336/600 추출 완료
#   📄 페이지 337/600 추출 완료
#   📄 페이지 338/600 추출 완료
#   📄 페이지 339/600 추출 완료
#   📄 페이지 340/600 추출 완료
#   📄 페이지 341/600 추출 완료
#   📄 페이지 342/600 추출 완료
#   📄 페이지 343/600 추출 완료
#   📄 페이지 344/600 추출 완료
#   📄 페이지 345/600 추출 완료
#   📄 페이지 346/600 추출 완료
#   📄 페이지 347/600 추출 완료
#   📄 페이지 348/600 추출 완료
#   📄 페이지 349/600 추출 완료
#   📄 페이지 350/600 추출 완료
#   📄 페이지 351/600 추출 완료
#   📄 페이지 352/600 추출 완료
#   📄 페이지 353/600 추출 완료
#   📄 페이지 354/600 추출 완료
#   📄 페이지 355/600 추출 완료
#   📄 페이지 356/600 추출 완료
#   📄 페이지 357/600 추출 완료
#   📄 페이지 358/600 추출 완료
#   📄 페이지 359/600 추출 완료
#   📄 페이지 360/600 추출 완료
#   📄 페이지 361/600 추출 완료
#   📄 페이지 362/600 추출 완료
#   📄 페이지 363/600 추출 완료
#   📄 페이지 364/600 추출 완료
#   📄 페이지 365/600 추출 완료
#   📄 페이지 366/600 추출 완료
#   📄 페이지 367/600 추출 완료
#   📄 페이지 368/600 추출 완료
#   📄 페이지 369/600 추출 완료
#   📄 페이지 370/600 추출 완료
#   📄 페이지 371/600 추출 완료
#   📄 페이지 372/600 추출 완료
#   📄 페이지 373/600 추출 완료
#   📄 페이지 374/600 추출 완료
#   📄 페이지 375/600 추출 완료
#   📄 페이지 376/600 추출 완료
#   📄 페이지 377/600 추출 완료
#   📄 페이지 378/600 추출 완료
#   📄 페이지 379/600 추출 완료
#   📄 페이지 380/600 추출 완료
#   📄 페이지 381/600 추출 완료
#   📄 페이지 382/600 추출 완료
#   📄 페이지 383/600 추출 완료
#   📄 페이지 384/600 추출 완료
#   📄 페이지 385/600 추출 완료
#   📄 페이지 386/600 추출 완료
#   📄 페이지 387/600 추출 완료
#   📄 페이지 388/600 추출 완료
#   📄 페이지 389/600 추출 완료
#   📄 페이지 390/600 추출 완료
#   📄 페이지 391/600 추출 완료
#   📄 페이지 392/600 추출 완료
#   📄 페이지 393/600 추출 완료
#   📄 페이지 394/600 추출 완료
#   📄 페이지 395/600 추출 완료
#   📄 페이지 396/600 추출 완료
#   📄 페이지 397/600 추출 완료
#   📄 페이지 398/600 추출 완료
#   📄 페이지 399/600 추출 완료
#   📄 페이지 400/600 추출 완료
#   📄 페이지 401/600 추출 완료
#   📄 페이지 402/600 추출 완료
#   📄 페이지 403/600 추출 완료
#   📄 페이지 404/600 추출 완료
#   📄 페이지 405/600 추출 완료
#   📄 페이지 406/600 추출 완료
#   📄 페이지 407/600 추출 완료
#   📄 페이지 408/600 추출 완료
#   📄 페이지 409/600 추출 완료
#   📄 페이지 410/600 추출 완료
#   📄 페이지 411/600 추출 완료
#   📄 페이지 412/600 추출 완료
#   📄 페이지 413/600 추출 완료
#   📄 페이지 414/600 추출 완료
#   📄 페이지 415/600 추출 완료
#   📄 페이지 416/600 추출 완료
#   📄 페이지 417/600 추출 완료
#   📄 페이지 418/600 추출 완료
#   📄 페이지 419/600 추출 완료
#   📄 페이지 420/600 추출 완료
#   📄 페이지 421/600 추출 완료
#   📄 페이지 422/600 추출 완료
#   📄 페이지 423/600 추출 완료
#   📄 페이지 424/600 추출 완료
#   📄 페이지 425/600 추출 완료
#   📄 페이지 426/600 추출 완료
#   📄 페이지 427/600 추출 완료
#   📄 페이지 428/600 추출 완료
#   📄 페이지 429/600 추출 완료
#   📄 페이지 430/600 추출 완료
#   📄 페이지 431/600 추출 완료
#   📄 페이지 432/600 추출 완료
#   📄 페이지 433/600 추출 완료
#   📄 페이지 434/600 추출 완료
#   📄 페이지 435/600 추출 완료
#   📄 페이지 436/600 추출 완료
#   📄 페이지 437/600 추출 완료
#   📄 페이지 438/600 추출 완료
#   📄 페이지 439/600 추출 완료
#   📄 페이지 440/600 추출 완료
#   📄 페이지 441/600 추출 완료
#   📄 페이지 442/600 추출 완료
#   📄 페이지 443/600 추출 완료
#   📄 페이지 444/600 추출 완료
#   📄 페이지 445/600 추출 완료
#   📄 페이지 446/600 추출 완료
#   📄 페이지 447/600 추출 완료
#   📄 페이지 448/600 추출 완료
#   📄 페이지 449/600 추출 완료
#   📄 페이지 450/600 추출 완료
#   📄 페이지 451/600 추출 완료
#   📄 페이지 452/600 추출 완료
#   📄 페이지 453/600 추출 완료
#   📄 페이지 454/600 추출 완료
#   📄 페이지 455/600 추출 완료
#   📄 페이지 456/600 추출 완료
#   📄 페이지 457/600 추출 완료
#   📄 페이지 458/600 추출 완료
#   📄 페이지 459/600 추출 완료
#   📄 페이지 460/600 추출 완료
#   📄 페이지 461/600 추출 완료
#   📄 페이지 462/600 추출 완료
#   📄 페이지 463/600 추출 완료
#   📄 페이지 464/600 추출 완료
#   📄 페이지 465/600 추출 완료
#   📄 페이지 466/600 추출 완료
#   📄 페이지 467/600 추출 완료
#   📄 페이지 468/600 추출 완료
#   📄 페이지 469/600 추출 완료
#   📄 페이지 470/600 추출 완료
#   📄 페이지 471/600 추출 완료
#   📄 페이지 472/600 추출 완료
#   📄 페이지 473/600 추출 완료
#   📄 페이지 474/600 추출 완료
#   📄 페이지 475/600 추출 완료
#   📄 페이지 476/600 추출 완료
#   📄 페이지 477/600 추출 완료
#   📄 페이지 478/600 추출 완료
#   📄 페이지 479/600 추출 완료
#   📄 페이지 480/600 추출 완료
#   📄 페이지 481/600 추출 완료
#   📄 페이지 482/600 추출 완료
#   📄 페이지 483/600 추출 완료
#   📄 페이지 484/600 추출 완료
#   📄 페이지 485/600 추출 완료
#   📄 페이지 486/600 추출 완료
#   📄 페이지 487/600 추출 완료
#   📄 페이지 488/600 추출 완료
#   📄 페이지 489/600 추출 완료
#   📄 페이지 490/600 추출 완료
#   📄 페이지 491/600 추출 완료
#   📄 페이지 492/600 추출 완료
#   📄 페이지 493/600 추출 완료
#   📄 페이지 494/600 추출 완료
#   📄 페이지 495/600 추출 완료
#   📄 페이지 496/600 추출 완료
#   📄 페이지 497/600 추출 완료
#   📄 페이지 498/600 추출 완료
#   📄 페이지 499/600 추출 완료
#   📄 페이지 500/600 추출 완료
#   📄 페이지 501/600 추출 완료
#   📄 페이지 502/600 추출 완료
#   📄 페이지 503/600 추출 완료
#   📄 페이지 504/600 추출 완료
#   📄 페이지 505/600 추출 완료
#   📄 페이지 506/600 추출 완료
#   📄 페이지 507/600 추출 완료
#   📄 페이지 508/600 추출 완료
#   📄 페이지 509/600 추출 완료
#   📄 페이지 510/600 추출 완료
#   📄 페이지 511/600 추출 완료
#   📄 페이지 512/600 추출 완료
#   📄 페이지 513/600 추출 완료
#   📄 페이지 514/600 추출 완료
#   📄 페이지 515/600 추출 완료
#   📄 페이지 516/600 추출 완료
#   📄 페이지 517/600 추출 완료
#   📄 페이지 518/600 추출 완료
#   📄 페이지 519/600 추출 완료
#   📄 페이지 520/600 추출 완료
#   📄 페이지 521/600 추출 완료
#   📄 페이지 522/600 추출 완료
#   📄 페이지 523/600 추출 완료
#   📄 페이지 524/600 추출 완료
#   📄 페이지 525/600 추출 완료
#   📄 페이지 526/600 추출 완료
#   📄 페이지 527/600 추출 완료
#   📄 페이지 528/600 추출 완료
#   📄 페이지 529/600 추출 완료
#   📄 페이지 530/600 추출 완료
#   📄 페이지 531/600 추출 완료
#   📄 페이지 532/600 추출 완료
#   📄 페이지 533/600 추출 완료
#   📄 페이지 534/600 추출 완료
#   📄 페이지 535/600 추출 완료
#   📄 페이지 536/600 추출 완료
#   📄 페이지 537/600 추출 완료
#   📄 페이지 538/600 추출 완료
#   📄 페이지 539/600 추출 완료
#   📄 페이지 540/600 추출 완료
#   📄 페이지 541/600 추출 완료
#   📄 페이지 542/600 추출 완료
#   📄 페이지 543/600 추출 완료
#   📄 페이지 544/600 추출 완료
#   📄 페이지 545/600 추출 완료
#   📄 페이지 546/600 추출 완료
#   📄 페이지 547/600 추출 완료
#   📄 페이지 548/600 추출 완료
#   📄 페이지 549/600 추출 완료
#   📄 페이지 550/600 추출 완료
#   📄 페이지 551/600 추출 완료
#   📄 페이지 552/600 추출 완료
#   📄 페이지 553/600 추출 완료
#   📄 페이지 554/600 추출 완료
#   📄 페이지 555/600 추출 완료
#   📄 페이지 556/600 추출 완료
#   📄 페이지 557/600 추출 완료
#   📄 페이지 558/600 추출 완료
#   📄 페이지 559/600 추출 완료
#   📄 페이지 560/600 추출 완료
#   📄 페이지 561/600 추출 완료
#   📄 페이지 562/600 추출 완료
#   📄 페이지 563/600 추출 완료
#   📄 페이지 564/600 추출 완료
#   📄 페이지 565/600 추출 완료
#   📄 페이지 566/600 추출 완료
#   📄 페이지 567/600 추출 완료
#   📄 페이지 568/600 추출 완료
#   📄 페이지 569/600 추출 완료
#   📄 페이지 570/600 추출 완료
#   📄 페이지 571/600 추출 완료
#   📄 페이지 572/600 추출 완료
#   📄 페이지 573/600 추출 완료
#   📄 페이지 574/600 추출 완료
#   📄 페이지 575/600 추출 완료
#   📄 페이지 576/600 추출 완료
#   📄 페이지 577/600 추출 완료
#   📄 페이지 578/600 추출 완료
#   📄 페이지 579/600 추출 완료
#   📄 페이지 580/600 추출 완료
#   📄 페이지 581/600 추출 완료
#   📄 페이지 582/600 추출 완료
#   📄 페이지 583/600 추출 완료
#   📄 페이지 584/600 추출 완료
#   📄 페이지 585/600 추출 완료
#   📄 페이지 586/600 추출 완료
#   📄 페이지 587/600 추출 완료
#   📄 페이지 588/600 추출 완료
#   📄 페이지 589/600 추출 완료
#   📄 페이지 590/600 추출 완료
#   📄 페이지 591/600 추출 완료
#   📄 페이지 592/600 추출 완료
#   📄 페이지 593/600 추출 완료
#   📄 페이지 594/600 추출 완료
#   📄 페이지 595/600 추출 완료
#   📄 페이지 596/600 추출 완료
#   📄 페이지 597/600 추출 완료
#   📄 페이지 598/600 추출 완료
#   📄 페이지 599/600 추출 완료
#   📄 페이지 600/600 추출 완료
#   📊 총 추출 텍스트: 560,107 문자
#   🔍 추출된 사례 수: 1
#   ✅ 표 정제 완료: C:\project\2stProject_jun\jun\과실비율PDF\과실비율 원본 PDF\231107_과실비율인정기준_온라인용_표정제.md
#   📄 생성된 문서 크기: 3,259 문자
#
# 📋 표 정제 결과 미리보기 (처음 50줄):
# ======================================================================
#   1: # 231107_과실비율인정기준_온라인용
#   2:
#   3: 📊 **총 1개 사례**
#   4:
#   5: ---
#   6:
#   7: ## 보24: 기준
#   8:
#   9: ### 📋 상황 설명
#  10:
#  11: - **(가)** 자전거 전용도로 (나) 자전거 전용차로 (다) 자전거 우선도로
#  12: - **(나)** 안전지대 벗어난 후
#  13:
#  14: ### 📊 과실비율 조정요소
#  15:
#  16: | 구분 | 조정 내용 | 조정값 |
#  17: |------|-----------|--------|
#  18: |  | 차48 | -1 |
#  19: |  | 차1 | -1 |
#  20: |  | 차2 | -1 |
#  21: |  | ⊙B차량 쪽에 비보호좌회전 표지가 있고 B차량이 녹색신호에 좌회전을 한 경우에는 차2 | -6 |
#  22: |  | 진입한 경우에는 신호위반 좌회전으로 차2 | -2 |
#  23: |  | 차3 | -1 |
#  24: |  | 차4 | -1 |
#  25: |  | ※舊 256, 396, 396 | -1 |
#  26: |  | 차5 | -1 |
#  27: |  | 차6 | -1 |
#  28: |  | 차7 | -1 |
#  29: |  | 차8 | -1 |
#  30: |  | 제3항을 감안하여 직진차량인 A차량의 비율을 차8 | -2 |
#  31: |  | 차9 | -1 |
#  32: |  | 차10 | -1 |
#  33: |  | 차11 | -1 |
#  34: |  | ※舊 259, 398 | -1 |
#  35: |  | ※舊 260, 398 | -2 |
#  36: |  | 차12 | -1 |
#  37: |  | 한 쪽에 일시정지 표지나 일방통행의 표지가 있는 경우(차7-1, 차7 | -2 |
#  38: |  | 차13 | -1 |
#  39: |  | ※舊 233-1, 348-1, 349 | -1 |
#  40: |  | 차14 | -1 |
#  41: |  | 차15 | -1 |
#  42: |  | 차16 | -1 |
#  43: |  | ⊙차16 | -1 |
#  44: |  | 차17 | -1 |
#  45: |  | 차18 | -1 |
#  46: |  | 차19 | -1 |
#  47: |  | 차20 | -1 |
#  48: |  | 차21 | -1 |
#  49: |  | 차31 | -1 |
#  50: |  | 좌회전, 횡단 등을 한 경우에는 차31 | -3 |
# ... (총 192줄 중 50줄만 표시)
#
# ======================================================================
#
# 📂 처리 대상: (최종)과실비율심의사례_(54MB).pdf
# 📄 PDF 처리 시작: (최종)과실비율심의사례_(54MB).pdf
#   📄 페이지 1/472 추출 완료
#   📄 페이지 2/472 추출 완료
#   📄 페이지 3/472 추출 완료
#   📄 페이지 4/472 추출 완료
#   📄 페이지 5/472 추출 완료
#   📄 페이지 6/472 추출 완료
#   📄 페이지 7/472 추출 완료
#   📄 페이지 8/472 추출 완료
#   📄 페이지 9/472 추출 완료
#   📄 페이지 10/472 추출 완료
#   📄 페이지 11/472 추출 완료
#   📄 페이지 12/472 추출 완료
#   📄 페이지 13/472 추출 완료
#   📄 페이지 14/472 추출 완료
#   📄 페이지 15/472 추출 완료
#   📄 페이지 16/472 추출 완료
#   📄 페이지 17/472 추출 완료
#   📄 페이지 18/472 추출 완료
#   📄 페이지 19/472 추출 완료
#   📄 페이지 20/472 추출 완료
#   📄 페이지 21/472 추출 완료
#   📄 페이지 22/472 추출 완료
#   📄 페이지 23/472 추출 완료
#   📄 페이지 24/472 추출 완료
#   📄 페이지 25/472 추출 완료
#   📄 페이지 26/472 추출 완료
#   📄 페이지 27/472 추출 완료
#   📄 페이지 28/472 추출 완료
#   📄 페이지 29/472 추출 완료
#   📄 페이지 30/472 추출 완료
#   📄 페이지 31/472 추출 완료
#   📄 페이지 32/472 추출 완료
#   📄 페이지 33/472 추출 완료
#   📄 페이지 34/472 추출 완료
#   📄 페이지 35/472 추출 완료
#   📄 페이지 36/472 추출 완료
#   📄 페이지 37/472 추출 완료
#   📄 페이지 38/472 추출 완료
#   📄 페이지 39/472 추출 완료
#   📄 페이지 40/472 추출 완료
#   📄 페이지 41/472 추출 완료
#   📄 페이지 42/472 추출 완료
#   📄 페이지 43/472 추출 완료
#   📄 페이지 44/472 추출 완료
#   📄 페이지 45/472 추출 완료
#   📄 페이지 46/472 추출 완료
#   📄 페이지 47/472 추출 완료
#   📄 페이지 48/472 추출 완료
#   📄 페이지 49/472 추출 완료
#   📄 페이지 50/472 추출 완료
#   📄 페이지 51/472 추출 완료
#   📄 페이지 52/472 추출 완료
#   📄 페이지 53/472 추출 완료
#   📄 페이지 54/472 추출 완료
#   📄 페이지 55/472 추출 완료
#   📄 페이지 56/472 추출 완료
#   📄 페이지 57/472 추출 완료
#   📄 페이지 58/472 추출 완료
#   📄 페이지 59/472 추출 완료
#   📄 페이지 60/472 추출 완료
#   📄 페이지 61/472 추출 완료
#   📄 페이지 62/472 추출 완료
#   📄 페이지 63/472 추출 완료
#   📄 페이지 64/472 추출 완료
#   📄 페이지 65/472 추출 완료
#   📄 페이지 66/472 추출 완료
#   📄 페이지 67/472 추출 완료
#   📄 페이지 68/472 추출 완료
#   📄 페이지 69/472 추출 완료
#   📄 페이지 70/472 추출 완료
#   📄 페이지 71/472 추출 완료
#   📄 페이지 72/472 추출 완료
#   📄 페이지 73/472 추출 완료
#   📄 페이지 74/472 추출 완료
#   📄 페이지 75/472 추출 완료
#   📄 페이지 76/472 추출 완료
#   📄 페이지 77/472 추출 완료
#   📄 페이지 78/472 추출 완료
#   📄 페이지 79/472 추출 완료
#   📄 페이지 80/472 추출 완료
#   📄 페이지 81/472 추출 완료
#   📄 페이지 82/472 추출 완료
#   📄 페이지 83/472 추출 완료
#   📄 페이지 84/472 추출 완료
#   📄 페이지 85/472 추출 완료
#   📄 페이지 86/472 추출 완료
#   📄 페이지 87/472 추출 완료
#   📄 페이지 88/472 추출 완료
#   📄 페이지 89/472 추출 완료
#   📄 페이지 90/472 추출 완료
#   📄 페이지 91/472 추출 완료
#   📄 페이지 92/472 추출 완료
#   📄 페이지 93/472 추출 완료
#   📄 페이지 94/472 추출 완료
#   📄 페이지 95/472 추출 완료
#   📄 페이지 96/472 추출 완료
#   📄 페이지 97/472 추출 완료
#   📄 페이지 98/472 추출 완료
#   📄 페이지 99/472 추출 완료
#   📄 페이지 100/472 추출 완료
#   📄 페이지 101/472 추출 완료
#   📄 페이지 102/472 추출 완료
#   📄 페이지 103/472 추출 완료
#   📄 페이지 104/472 추출 완료
#   📄 페이지 105/472 추출 완료
#   📄 페이지 106/472 추출 완료
#   📄 페이지 107/472 추출 완료
#   📄 페이지 108/472 추출 완료
#   📄 페이지 109/472 추출 완료
#   📄 페이지 110/472 추출 완료
#   📄 페이지 111/472 추출 완료
#   📄 페이지 112/472 추출 완료
#   📄 페이지 113/472 추출 완료
#   📄 페이지 114/472 추출 완료
#   📄 페이지 115/472 추출 완료
#   📄 페이지 116/472 추출 완료
#   📄 페이지 117/472 추출 완료
#   📄 페이지 118/472 추출 완료
#   📄 페이지 119/472 추출 완료
#   📄 페이지 120/472 추출 완료
#   📄 페이지 121/472 추출 완료
#   📄 페이지 122/472 추출 완료
#   📄 페이지 123/472 추출 완료
#   📄 페이지 124/472 추출 완료
#   📄 페이지 125/472 추출 완료
#   📄 페이지 126/472 추출 완료
#   📄 페이지 127/472 추출 완료
#   📄 페이지 128/472 추출 완료
#   📄 페이지 129/472 추출 완료
#   📄 페이지 130/472 추출 완료
#   📄 페이지 131/472 추출 완료
#   📄 페이지 132/472 추출 완료
#   📄 페이지 133/472 추출 완료
#   📄 페이지 134/472 추출 완료
#   📄 페이지 135/472 추출 완료
#   📄 페이지 136/472 추출 완료
#   📄 페이지 137/472 추출 완료
#   📄 페이지 138/472 추출 완료
#   📄 페이지 139/472 추출 완료
#   📄 페이지 140/472 추출 완료
#   📄 페이지 141/472 추출 완료
#   📄 페이지 142/472 추출 완료
#   📄 페이지 143/472 추출 완료
#   📄 페이지 144/472 추출 완료
#   📄 페이지 145/472 추출 완료
#   📄 페이지 146/472 추출 완료
#   📄 페이지 147/472 추출 완료
#   📄 페이지 148/472 추출 완료
#   📄 페이지 149/472 추출 완료
#   📄 페이지 150/472 추출 완료
#   📄 페이지 151/472 추출 완료
#   📄 페이지 152/472 추출 완료
#   📄 페이지 153/472 추출 완료
#   📄 페이지 154/472 추출 완료
#   📄 페이지 155/472 추출 완료
#   📄 페이지 156/472 추출 완료
#   📄 페이지 157/472 추출 완료
#   📄 페이지 158/472 추출 완료
#   📄 페이지 159/472 추출 완료
#   📄 페이지 160/472 추출 완료
#   📄 페이지 161/472 추출 완료
#   📄 페이지 162/472 추출 완료
#   📄 페이지 163/472 추출 완료
#   📄 페이지 164/472 추출 완료
#   📄 페이지 165/472 추출 완료
#   📄 페이지 166/472 추출 완료
#   📄 페이지 167/472 추출 완료
#   📄 페이지 168/472 추출 완료
#   📄 페이지 169/472 추출 완료
#   📄 페이지 170/472 추출 완료
#   📄 페이지 171/472 추출 완료
#   📄 페이지 172/472 추출 완료
#   📄 페이지 173/472 추출 완료
#   📄 페이지 174/472 추출 완료
#   📄 페이지 175/472 추출 완료
#   📄 페이지 176/472 추출 완료
#   📄 페이지 177/472 추출 완료
#   📄 페이지 178/472 추출 완료
#   📄 페이지 179/472 추출 완료
#   📄 페이지 180/472 추출 완료
#   📄 페이지 181/472 추출 완료
#   📄 페이지 182/472 추출 완료
#   📄 페이지 183/472 추출 완료
#   📄 페이지 184/472 추출 완료
#   📄 페이지 185/472 추출 완료
#   📄 페이지 186/472 추출 완료
#   📄 페이지 187/472 추출 완료
#   📄 페이지 188/472 추출 완료
#   📄 페이지 189/472 추출 완료
#   📄 페이지 190/472 추출 완료
#   📄 페이지 191/472 추출 완료
#   📄 페이지 192/472 추출 완료
#   📄 페이지 193/472 추출 완료
#   📄 페이지 194/472 추출 완료
#   📄 페이지 195/472 추출 완료
#   📄 페이지 196/472 추출 완료
#   📄 페이지 197/472 추출 완료
#   📄 페이지 198/472 추출 완료
#   📄 페이지 199/472 추출 완료
#   📄 페이지 200/472 추출 완료
#   📄 페이지 201/472 추출 완료
#   📄 페이지 202/472 추출 완료
#   📄 페이지 203/472 추출 완료
#   📄 페이지 204/472 추출 완료
#   📄 페이지 205/472 추출 완료
#   📄 페이지 206/472 추출 완료
#   📄 페이지 207/472 추출 완료
#   📄 페이지 208/472 추출 완료
#   📄 페이지 209/472 추출 완료
#   📄 페이지 210/472 추출 완료
#   📄 페이지 211/472 추출 완료
#   📄 페이지 212/472 추출 완료
#   📄 페이지 213/472 추출 완료
#   📄 페이지 214/472 추출 완료
#   📄 페이지 215/472 추출 완료
#   📄 페이지 216/472 추출 완료
#   📄 페이지 217/472 추출 완료
#   📄 페이지 218/472 추출 완료
#   📄 페이지 219/472 추출 완료
#   📄 페이지 220/472 추출 완료
#   📄 페이지 221/472 추출 완료
#   📄 페이지 222/472 추출 완료
#   📄 페이지 223/472 추출 완료
#   📄 페이지 224/472 추출 완료
#   📄 페이지 225/472 추출 완료
#   📄 페이지 226/472 추출 완료
#   📄 페이지 227/472 추출 완료
#   📄 페이지 228/472 추출 완료
#   📄 페이지 229/472 추출 완료
#   📄 페이지 230/472 추출 완료
#   📄 페이지 231/472 추출 완료
#   📄 페이지 232/472 추출 완료
#   📄 페이지 233/472 추출 완료
#   📄 페이지 234/472 추출 완료
#   📄 페이지 235/472 추출 완료
#   📄 페이지 236/472 추출 완료
#   📄 페이지 237/472 추출 완료
#   📄 페이지 238/472 추출 완료
#   📄 페이지 239/472 추출 완료
#   📄 페이지 240/472 추출 완료
#   📄 페이지 241/472 추출 완료
#   📄 페이지 242/472 추출 완료
#   📄 페이지 243/472 추출 완료
#   📄 페이지 244/472 추출 완료
#   📄 페이지 245/472 추출 완료
#   📄 페이지 246/472 추출 완료
#   📄 페이지 247/472 추출 완료
#   📄 페이지 248/472 추출 완료
#   📄 페이지 249/472 추출 완료
#   📄 페이지 250/472 추출 완료
#   📄 페이지 251/472 추출 완료
#   📄 페이지 252/472 추출 완료
#   📄 페이지 253/472 추출 완료
#   📄 페이지 254/472 추출 완료
#   📄 페이지 255/472 추출 완료
#   📄 페이지 256/472 추출 완료
#   📄 페이지 257/472 추출 완료
#   📄 페이지 258/472 추출 완료
#   📄 페이지 259/472 추출 완료
#   📄 페이지 260/472 추출 완료
#   📄 페이지 261/472 추출 완료
#   📄 페이지 262/472 추출 완료
#   📄 페이지 263/472 추출 완료
#   📄 페이지 264/472 추출 완료
#   📄 페이지 265/472 추출 완료
#   📄 페이지 266/472 추출 완료
#   📄 페이지 267/472 추출 완료
#   📄 페이지 268/472 추출 완료
#   📄 페이지 269/472 추출 완료
#   📄 페이지 270/472 추출 완료
#   📄 페이지 271/472 추출 완료
#   📄 페이지 272/472 추출 완료
#   📄 페이지 273/472 추출 완료
#   📄 페이지 274/472 추출 완료
#   📄 페이지 275/472 추출 완료
#   📄 페이지 276/472 추출 완료
#   📄 페이지 277/472 추출 완료
#   📄 페이지 278/472 추출 완료
#   📄 페이지 279/472 추출 완료
#   📄 페이지 280/472 추출 완료
#   📄 페이지 281/472 추출 완료
#   📄 페이지 282/472 추출 완료
#   📄 페이지 283/472 추출 완료
#   📄 페이지 284/472 추출 완료
#   📄 페이지 285/472 추출 완료
#   📄 페이지 286/472 추출 완료
#   📄 페이지 287/472 추출 완료
#   📄 페이지 288/472 추출 완료
#   📄 페이지 289/472 추출 완료
#   📄 페이지 290/472 추출 완료
#   📄 페이지 291/472 추출 완료
#   📄 페이지 292/472 추출 완료
#   📄 페이지 293/472 추출 완료
#   📄 페이지 294/472 추출 완료
#   📄 페이지 295/472 추출 완료
#   📄 페이지 296/472 추출 완료
#   📄 페이지 297/472 추출 완료
#   📄 페이지 298/472 추출 완료
#   📄 페이지 299/472 추출 완료
#   📄 페이지 300/472 추출 완료
#   📄 페이지 301/472 추출 완료
#   📄 페이지 302/472 추출 완료
#   📄 페이지 303/472 추출 완료
#   📄 페이지 304/472 추출 완료
#   📄 페이지 305/472 추출 완료
#   📄 페이지 306/472 추출 완료
#   📄 페이지 307/472 추출 완료
#   📄 페이지 308/472 추출 완료
#   📄 페이지 309/472 추출 완료
#   📄 페이지 310/472 추출 완료
#   📄 페이지 311/472 추출 완료
#   📄 페이지 312/472 추출 완료
#   📄 페이지 313/472 추출 완료
#   📄 페이지 314/472 추출 완료
#   📄 페이지 315/472 추출 완료
#   📄 페이지 316/472 추출 완료
#   📄 페이지 317/472 추출 완료
#   📄 페이지 318/472 추출 완료
#   📄 페이지 319/472 추출 완료
#   📄 페이지 320/472 추출 완료
#   📄 페이지 321/472 추출 완료
#   📄 페이지 322/472 추출 완료
#   📄 페이지 323/472 추출 완료
#   📄 페이지 324/472 추출 완료
#   📄 페이지 325/472 추출 완료
#   📄 페이지 326/472 추출 완료
#   📄 페이지 327/472 추출 완료
#   📄 페이지 328/472 추출 완료
#   📄 페이지 329/472 추출 완료
#   📄 페이지 330/472 추출 완료
#   📄 페이지 331/472 추출 완료
#   📄 페이지 332/472 추출 완료
#   📄 페이지 333/472 추출 완료
#   📄 페이지 334/472 추출 완료
#   📄 페이지 335/472 추출 완료
#   📄 페이지 336/472 추출 완료
#   📄 페이지 337/472 추출 완료
#   📄 페이지 338/472 추출 완료
#   📄 페이지 339/472 추출 완료
#   📄 페이지 340/472 추출 완료
#   📄 페이지 341/472 추출 완료
#   📄 페이지 342/472 추출 완료
#   📄 페이지 343/472 추출 완료
#   📄 페이지 344/472 추출 완료
#   📄 페이지 345/472 추출 완료
#   📄 페이지 346/472 추출 완료
#   📄 페이지 347/472 추출 완료
#   📄 페이지 348/472 추출 완료
#   📄 페이지 349/472 추출 완료
#   📄 페이지 350/472 추출 완료
#   📄 페이지 351/472 추출 완료
#   📄 페이지 352/472 추출 완료
#   📄 페이지 353/472 추출 완료
#   📄 페이지 354/472 추출 완료
#   📄 페이지 355/472 추출 완료
#   📄 페이지 356/472 추출 완료
#   📄 페이지 357/472 추출 완료
#   📄 페이지 358/472 추출 완료
#   📄 페이지 359/472 추출 완료
#   📄 페이지 360/472 추출 완료
#   📄 페이지 361/472 추출 완료
#   📄 페이지 362/472 추출 완료
#   📄 페이지 363/472 추출 완료
#   📄 페이지 364/472 추출 완료
#   📄 페이지 365/472 추출 완료
#   📄 페이지 366/472 추출 완료
#   📄 페이지 367/472 추출 완료
#   📄 페이지 368/472 추출 완료
#   📄 페이지 369/472 추출 완료
#   📄 페이지 370/472 추출 완료
#   📄 페이지 371/472 추출 완료
#   📄 페이지 372/472 추출 완료
#   📄 페이지 373/472 추출 완료
#   📄 페이지 374/472 추출 완료
#   📄 페이지 375/472 추출 완료
#   📄 페이지 376/472 추출 완료
#   📄 페이지 377/472 추출 완료
#   📄 페이지 378/472 추출 완료
#   📄 페이지 379/472 추출 완료
#   📄 페이지 380/472 추출 완료
#   📄 페이지 381/472 추출 완료
#   📄 페이지 382/472 추출 완료
#   📄 페이지 383/472 추출 완료
#   📄 페이지 384/472 추출 완료
#   📄 페이지 385/472 추출 완료
#   📄 페이지 386/472 추출 완료
#   📄 페이지 387/472 추출 완료
#   📄 페이지 388/472 추출 완료
#   📄 페이지 389/472 추출 완료
#   📄 페이지 390/472 추출 완료
#   📄 페이지 391/472 추출 완료
#   📄 페이지 392/472 추출 완료
#   📄 페이지 393/472 추출 완료
#   📄 페이지 394/472 추출 완료
#   📄 페이지 395/472 추출 완료
#   📄 페이지 396/472 추출 완료
#   📄 페이지 397/472 추출 완료
#   📄 페이지 398/472 추출 완료
#   📄 페이지 399/472 추출 완료
#   📄 페이지 400/472 추출 완료
#   📄 페이지 401/472 추출 완료
#   📄 페이지 402/472 추출 완료
#   📄 페이지 403/472 추출 완료
#   📄 페이지 404/472 추출 완료
#   📄 페이지 405/472 추출 완료
#   📄 페이지 406/472 추출 완료
#   📄 페이지 407/472 추출 완료
#   📄 페이지 408/472 추출 완료
#   📄 페이지 409/472 추출 완료
#   📄 페이지 410/472 추출 완료
#   📄 페이지 411/472 추출 완료
#   📄 페이지 412/472 추출 완료
#   📄 페이지 413/472 추출 완료
#   📄 페이지 414/472 추출 완료
#   📄 페이지 415/472 추출 완료
#   📄 페이지 416/472 추출 완료
#   📄 페이지 417/472 추출 완료
#   📄 페이지 418/472 추출 완료
#   📄 페이지 419/472 추출 완료
#   📄 페이지 420/472 추출 완료
#   📄 페이지 421/472 추출 완료
#   📄 페이지 422/472 추출 완료
#   📄 페이지 423/472 추출 완료
#   📄 페이지 424/472 추출 완료
#   📄 페이지 425/472 추출 완료
#   📄 페이지 426/472 추출 완료
#   📄 페이지 427/472 추출 완료
#   📄 페이지 428/472 추출 완료
#   📄 페이지 429/472 추출 완료
#   📄 페이지 430/472 추출 완료
#   📄 페이지 431/472 추출 완료
#   📄 페이지 432/472 추출 완료
#   📄 페이지 433/472 추출 완료
#   📄 페이지 434/472 추출 완료
#   📄 페이지 435/472 추출 완료
#   📄 페이지 436/472 추출 완료
#   📄 페이지 437/472 추출 완료
#   📄 페이지 438/472 추출 완료
#   📄 페이지 439/472 추출 완료
#   📄 페이지 440/472 추출 완료
#   📄 페이지 441/472 추출 완료
#   📄 페이지 442/472 추출 완료
#   📄 페이지 443/472 추출 완료
#   📄 페이지 444/472 추출 완료
#   📄 페이지 445/472 추출 완료
#   📄 페이지 446/472 추출 완료
#   📄 페이지 447/472 추출 완료
#   📄 페이지 448/472 추출 완료
#   📄 페이지 449/472 추출 완료
#   📄 페이지 450/472 추출 완료
#   📄 페이지 451/472 추출 완료
#   📄 페이지 452/472 추출 완료
#   📄 페이지 453/472 추출 완료
#   📄 페이지 454/472 추출 완료
#   📄 페이지 455/472 추출 완료
#   📄 페이지 456/472 추출 완료
#   📄 페이지 457/472 추출 완료
#   📄 페이지 458/472 추출 완료
#   📄 페이지 459/472 추출 완료
#   📄 페이지 460/472 추출 완료
#   📄 페이지 461/472 추출 완료
#   📄 페이지 462/472 추출 완료
#   📄 페이지 463/472 추출 완료
#   📄 페이지 464/472 추출 완료
#   📄 페이지 465/472 추출 완료
#   📄 페이지 466/472 추출 완료
#   📄 페이지 467/472 추출 완료
#   📄 페이지 468/472 추출 완료
#   📄 페이지 469/472 추출 완료
#   📄 페이지 470/472 추출 완료
#   📄 페이지 471/472 추출 완료
#   📄 페이지 472/472 추출 완료
#   📊 총 추출 텍스트: 441,754 문자
#   🔍 추출된 사례 수: 3
#   ✅ 표 정제 완료: C:\project\2stProject_jun\jun\과실비율PDF\과실비율 원본 PDF\(최종)과실비율심의사례_(54MB)_표정제.md
#   📄 생성된 문서 크기: 1,108 문자
#
# 📋 표 정제 결과 미리보기 (처음 50줄):
# ======================================================================
#   1: # (최종)과실비율심의사례_(54MB)
#   2:
#   3: 📊 **총 3개 사례**
#   4:
#   5: ---
#   6:
#   7: ## 카1551: 판결), 후행차량의 위험을 초래하지 않도록 차
#   8:
#   9: ### 📊 과실비율 조정요소
#  10:
#  11: | 구분 | 조정 내용 | 조정값 |
#  12: |------|-----------|--------|
#  13: |  | 2017 | -064915 |
#  14:
#  15: ### 📜 관련 법령
#  16:
#  17: - 도로교통법 제19조
#  18: - 도로교통법 제48조
#  19:
#  20: ---
#  21:
#  22: ## 카1551: 판결), 후행차량의 위험을 초래하지 않도록 차
#  23:
#  24: ### 📊 과실비율 조정요소
#  25:
#  26: | 구분 | 조정 내용 | 조정값 |
#  27: |------|-----------|--------|
#  28: |  | 2019 | -007380 |
#  29:
#  30: ### 📜 관련 법령
#  31:
#  32: - 도로교통법 제19조
#  33: - 도로교통법 제48조
#  34:
#  35: ---
#  36:
#  37: ## 카1551: 판결), 후행차량의 위험을 초래하지 않도록 차
#  38:
#  39: ### 📋 상황 설명
#  40:
#  41: - **(가)** 도표 263을 준용하되, 이륜차는 차량에 비하여 가
#  42: - **(나)** 추월차량은 도로교통법 제25조 제1항의 교차로
#  43: - **(다)** 우회전차량인 A이륜차가 후진입한 경우에 도표
#  44:
#  45: ### 📊 과실비율 조정요소
#  46:
#  47: | 구분 | 조정 내용 | 조정값 |
#  48: |------|-----------|--------|
#  49: |  | 252 | -1 |
#  50: |  | 2019 | -011881 |
# ... (총 80줄 중 50줄만 표시)
#
# ======================================================================
#
# 📊 전체 변환 결과 요약
# ======================================================================
# 1. 231107_과실비율인정기준_온라인용_표정제.md
#    📄 추출된 사례: 1개
#    📝 문서 크기: 3,259 문자
#    💾 저장 위치: C:\project\2stProject_jun\jun\과실비율PDF\과실비율 원본 PDF\231107_과실비율인정기준_온라인용_표정제.md
#
# 2. (최종)과실비율심의사례_(54MB)_표정제.md
#    📄 추출된 사례: 3개
#    📝 문서 크기: 1,108 문자
#    💾 저장 위치: C:\project\2stProject_jun\jun\과실비율PDF\과실비율 원본 PDF\(최종)과실비율심의사례_(54MB)_표정제.md
#
# 📈 총 사례 수: 4개
# 📄 총 문서 크기: 4,367 문자
# 📁 생성된 파일: 2개
#
# 🎯 다음 단계:
# 1. 생성된 표 구조 마크다운 확인
# 2. 필요시 조정 및 수정
# 3. DOCS 통합 변환 또는 RAG 데이터셋 생성

# %%
import re
import os

class KoreanMarkdownCleaner:
    def __init__(self):
        # 정제 통계를 위한 카운터
        self.stats = {
            'lines_processed': 0,
            'numbering_fixed': 0,
            'empty_lines_removed': 0,
            'whitespace_normalized': 0,
            'korean_numbering_detected': 0
        }
        
        # 한국어 번호 체계 패턴 정의
        self.korean_patterns = {
            # 가, 나, 다 패턴
            'korean_letters': r'^\s*([가-힣])\s*[\.\)]\s*(.*)',
            # 1, 2, 3 패턴
            'arabic_numbers': r'^\s*(\d+)\s*[\.\)]\s*(.*)',
            # ①, ②, ③ 둥근 숫자 패턴
            'circled_numbers': r'^\s*([①-⑳㉑-㉟])\s*(.*)',
            # ㄱ, ㄴ, ㄷ 자음 패턴
            'consonants': r'^\s*([ㄱ-ㅎ])\s*[\.\)]\s*(.*)',
            # (1), (2), (3) 괄호 숫자 패턴
            'parenthesis_numbers': r'^\s*\((\d+)\)\s*(.*)',
            # 가), 나), 다) 패턴
            'korean_parenthesis': r'^\s*([가-힣])\)\s*(.*)',
            # 1), 2), 3) 패턴
            'number_parenthesis': r'^\s*(\d+)\)\s*(.*)'
        }
    
    def clean_markdown_file(self, input_path, output_path=None):
        """
        마크다운 파일을 읽어서 정제하고 저장
        """
        try:
            with open(input_path, 'r', encoding='utf-8') as file:
                content = file.read()
        except UnicodeDecodeError:
            # UTF-8로 읽기 실패 시 다른 인코딩 시도
            with open(input_path, 'r', encoding='cp949') as file:
                content = file.read()
        
        cleaned_content = self.clean_markdown_text(content)
        
        # 출력 경로가 없으면 원본 파일명에 _cleaned 추가
        if output_path is None:
            base, ext = os.path.splitext(input_path)
            output_path = f"{base}_cleaned{ext}"
        
        with open(output_path, 'w', encoding='utf-8') as file:
            file.write(cleaned_content)
        
        return output_path, self.stats
    
    def clean_markdown_text(self, text):
        """
        마크다운 텍스트를 정제하는 메인 함수
        """
        lines = text.split('\n')
        cleaned_lines = []
        
        for i, line in enumerate(lines):
            self.stats['lines_processed'] += 1
            
            # 1. 기본 공백 정리
            cleaned_line = self._normalize_whitespace(line)
            
            # 2. 빈 줄 처리
            if not cleaned_line.strip():
                if i > 0 and cleaned_lines and cleaned_lines[-1].strip():
                    cleaned_lines.append('')
                continue
            
            # 3. 한국어 번호 체계 정제
            cleaned_line = self._process_korean_numbering(cleaned_line)
            
            cleaned_lines.append(cleaned_line)
        
        # 4. 연속된 빈 줄 제거
        result = self._remove_excessive_empty_lines(cleaned_lines)
        
        # 5. 최종 구조 정리
        result = self._finalize_structure(result)
        
        return '\n'.join(result)
    
    def _normalize_whitespace(self, line):
        """
        기본적인 공백 정규화
        """
        # 탭을 스페이스로 변환
        line = line.replace('\t', '    ')
        # 연속된 스페이스를 단일 스페이스로
        line = re.sub(r' {2,}', ' ', line)
        # 줄 끝 공백 제거
        return line.rstrip()
    
    def _process_korean_numbering(self, line):
        """
        한국어 번호 체계를 마크다운 리스트로 변환
        """
        original_line = line
        
        # 각 패턴을 순서대로 확인
        for pattern_name, pattern in self.korean_patterns.items():
            match = re.match(pattern, line)
            if match:
                self.stats['korean_numbering_detected'] += 1
                self.stats['numbering_fixed'] += 1
                
                if pattern_name == 'korean_letters':
                    # 가, 나, 다 -> 1. 가항목, 2. 나항목
                    letter, content = match.groups()
                    order = ord(letter) - ord('가') + 1
                    return f"{order}. **{letter}항목** {content.strip()}"
                
                elif pattern_name == 'arabic_numbers':
                    # 1, 2, 3 -> 표준 마크다운 리스트
                    number, content = match.groups()
                    return f"{number}. {content.strip()}"
                
                elif pattern_name == 'circled_numbers':
                    # ①, ②, ③ -> (1), (2), (3)
                    circled, content = match.groups()
                    number = self._circled_to_number(circled)
                    return f"   ({number}) {content.strip()}"
                
                elif pattern_name == 'consonants':
                    # ㄱ, ㄴ, ㄷ -> - ㄱ항목, - ㄴ항목
                    consonant, content = match.groups()
                    return f"   - **{consonant}항목** {content.strip()}"
                
                elif pattern_name == 'parenthesis_numbers':
                    # (1), (2), (3) -> 서브리스트
                    number, content = match.groups()
                    return f"   ({number}) {content.strip()}"
                
                elif pattern_name == 'korean_parenthesis':
                    # 가), 나), 다) -> 서브리스트
                    letter, content = match.groups()
                    return f"   - **{letter}항목** {content.strip()}"
                
                elif pattern_name == 'number_parenthesis':
                    # 1), 2), 3) -> 서브리스트
                    number, content = match.groups()
                    return f"   - {content.strip()}"
        
        return line
    
    def _circled_to_number(self, circled_char):
        """
        둥근 숫자를 일반 숫자로 변환
        """
        circled_map = {
            '①': 1, '②': 2, '③': 3, '④': 4, '⑤': 5,
            '⑥': 6, '⑦': 7, '⑧': 8, '⑨': 9, '⑩': 10,
            '⑪': 11, '⑫': 12, '⑬': 13, '⑭': 14, '⑮': 15,
            '⑯': 16, '⑰': 17, '⑱': 18, '⑲': 19, '⑳': 20,
            '㉑': 21, '㉒': 22, '㉓': 23, '㉔': 24, '㉕': 25,
            '㉖': 26, '㉗': 27, '㉘': 28, '㉙': 29, '㉚': 30,
            '㉛': 31, '㉜': 32, '㉝': 33, '㉞': 34, '㉟': 35
        }
        return circled_map.get(circled_char, 1)
    
    def _remove_excessive_empty_lines(self, lines):
        """
        연속된 빈 줄을 단일 빈 줄로 변환
        """
        result = []
        prev_empty = False
        
        for line in lines:
            if not line.strip():
                if not prev_empty:
                    result.append('')
                    prev_empty = True
                else:
                    self.stats['empty_lines_removed'] += 1
            else:
                result.append(line)
                prev_empty = False
        
        return result
    
    def _finalize_structure(self, lines):
        """
        최종 구조 정리
        """
        result = []
        
        for i, line in enumerate(lines):
            # 리스트 항목 간 적절한 간격 추가
            if i > 0 and lines[i-1].strip():
                # 메인 항목 앞에 빈 줄 추가
                if re.match(r'^\d+\.\s', line) and not re.match(r'^\d+\.\s', lines[i-1]):
                    result.append('')
            
            result.append(line)
        
        return result
    
    def print_stats(self):
        """
        정제 통계 출력
        """
        print("=== 정제 통계 ===")
        print(f"처리된 줄 수: {self.stats['lines_processed']}")
        print(f"한국어 번호 체계 감지: {self.stats['korean_numbering_detected']}")
        print(f"번호 체계 수정: {self.stats['numbering_fixed']}")
        print(f"제거된 빈 줄: {self.stats['empty_lines_removed']}")

# 사용 예제
def main():
    cleaner = KoreanMarkdownCleaner()
    
    # 샘플 텍스트로 테스트
    sample_text = """
가. 첫 번째 항목입니다
    ① 세부 항목 1
    ② 세부 항목 2
    
나. 두 번째 항목입니다
    ㄱ. 하위 항목 가
    ㄴ. 하위 항목 나
    
1 세 번째 항목
(1) 괄호 항목 1
(2) 괄호 항목 2

다) 네 번째 항목
1) 번호 항목
2) 번호 항목 2
"""
    
    print("원본 텍스트:")
    print(sample_text)
    print("\n" + "="*50 + "\n")
    
    cleaned = cleaner.clean_markdown_text(sample_text)
    print("정제된 텍스트:")
    print(cleaned)
    
    cleaner.print_stats()

if __name__ == "__main__":
    # 파일 처리 예제
    # output_path, stats = cleaner.clean_markdown_file("input.md", "output.md")
    
    # 샘플 테스트 실행
    main()
